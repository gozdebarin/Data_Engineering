# %%
# https://spotipy.readthedocs.io/en/2.19.0/

# Install spotipy
# As google colab starts each session like a new computer, we must install this each time.
# If you are working on your local machine, you only need to install it once.
# !pip install spotipy --upgrade
# !pip install urllib3 --upgrade
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# Collecting spotipy
#   Downloading spotipy-2.22.1-py3-none-any.whl (28 kB)
# Collecting redis>=3.5.3
#   Downloading redis-4.5.1-py3-none-any.whl (238 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 238.5/238.5 KB 7.4 MB/s eta 0:00:00
# Requirement already satisfied: requests>=2.25.0 in /usr/local/lib/python3.8/dist-packages (from spotipy) (2.25.1)
# Collecting urllib3>=1.26.0
#   Downloading urllib3-1.26.14-py2.py3-none-any.whl (140 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 140.6/140.6 KB 5.8 MB/s eta 0:00:00
# Requirement already satisfied: six>=1.15.0 in /usr/local/lib/python3.8/dist-packages (from spotipy) (1.15.0)
# Requirement already satisfied: async-timeout>=4.0.2 in /usr/local/lib/python3.8/dist-packages (from redis>=3.5.3->spotipy) (4.0.2)
# Requirement already satisfied: chardet<5,>=3.0.2 in /usr/local/lib/python3.8/dist-packages (from requests>=2.25.0->spotipy) (4.0.0)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.8/dist-packages (from requests>=2.25.0->spotipy) (2022.12.7)
# Requirement already satisfied: idna<3,>=2.5 in /usr/local/lib/python3.8/dist-packages (from requests>=2.25.0->spotipy) (2.10)
# Installing collected packages: urllib3, redis, spotipy
#   Attempting uninstall: urllib3
#     Found existing installation: urllib3 1.24.3
#     Uninstalling urllib3-1.24.3:
#       Successfully uninstalled urllib3-1.24.3
# Successfully installed redis-4.5.1 spotipy-2.22.1 urllib3-1.26.14
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# Requirement already satisfied: urllib3 in /usr/local/lib/python3.8/dist-packages (1.26.14)

# %%
# import libraries
import pandas as pd
import requests

# %% [markdown]
# ## Requests
#
# When we make a request, we get a requests.Response object in return. The requests.Response object contains the server's response to the HTTP request. Part of this response is a number - which represents whether we received the information we wanted or not. If you get a number that you don't understand, these cats will help you: https://http.cat/
#
# More often than not you'll receive:
#
# 200: Success!
#
# 401: Unauthorized client error status: lack of valid authentication credentials
#
# 403: The server understood the request but refuses to authorize it

# %%
# find url and store it in a variable
google = requests.get("https://developers.google.com")
print("Google:", google.status_code)

NBA = requests.get("https://api.sportsdata.io/api/nba/fantasy/json/CurrentSeason")
print("NBA:", NBA.status_code) 

wbscs = requests.get("https://www.wbscodingschool.com/")
print("WBS CS: ", wbscs.status_code)
# Out:
# Google: 200
# NBA: 401
# WBS CS:  403

# %% [markdown]
# ## JSON

# %% [markdown]
# ### Making a request and viewing the JSON
#
# https://docs.python.org/3/library/json.html
#
# JSON has quickly become the de facto standard for information exchange. JSON supports primitive types, like strings and numbers, as well as nested lists and objects. It looks like nested python dictionaries:
#
# `{"firstname": "Harry",
# "lastname": "Noah",
# "city": "Berlin",
# "dogs": [{"name": "rover", "breed": "labrador"}, {"name": "pip", "breed": "spaniel"}],
# "cars": "none"}`

# %%
# import libraries
import json

# %%
# make the request
response = requests.get("https://jsonplaceholder.typicode.com/users")

# %%
# check the HTTP code
response
# Out:
# <Response [200]>

# %%
# format scraped data into JSON format
response.json()
# Out:
# [{'id': 1,
#   'name': 'Leanne Graham',
#   'username': 'Bret',
#   'email': 'Sincere@april.biz',
#   'address': {'street': 'Kulas Light',
#    'suite': 'Apt. 556',
#    'city': 'Gwenborough',
#    'zipcode': '92998-3874',
#    'geo': {'lat': '-37.3159', 'lng': '81.1496'}},
#   'phone': '1-770-736-8031 x56442',
#   'website': 'hildegard.org',
#   'company': {'name': 'Romaguera-Crona',
#    'catchPhrase': 'Multi-layered client-server neural-net',
#    'bs': 'harness real-time e-markets'}},
#  {'id': 2,
#   'name': 'Ervin Howell',
#   'username': 'Antonette',
#   'email': 'Shanna@melissa.tv',
#   'address': {'street': 'Victor Plains',
#    'suite': 'Suite 879',
#    'city': 'Wisokyburgh',
#    'zipcode': '90566-7771',
#    'geo': {'lat': '-43.9509', 'lng': '-34.4618'}},
#   'phone': '010-692-6593 x09125',
#   'website': 'anastasia.net',
#   'company': {'name': 'Deckow-Crist',
#    'catchPhrase': 'Proactive didactic contingency',
#    'bs': 'synergize scalable supply-chains'}},
#  {'id': 3,
#   'name': 'Clementine Bauch',
#   'username': 'Samantha',
#   'email': 'Nathan@yesenia.net',
#   'address': {'street': 'Douglas Extension',
#    'suite': 'Suite 847',
#    'city': 'McKenziehaven',
#    'zipcode': '59590-4157',
#    'geo': {'lat': '-68.6102', 'lng': '-47.0653'}},
#   'phone': '1-463-123-4447',
#   'website': 'ramiro.info',
#   'company': {'name': 'Romaguera-Jacobson',
#    'catchPhrase': 'Face to face bifurcated interface',
#    'bs': 'e-enable strategic applications'}},
#  {'id': 4,
#   'name': 'Patricia Lebsack',
#   'username': 'Karianne',
#   'email': 'Julianne.OConner@kory.org',
#   'address': {'street': 'Hoeger Mall',
#    'suite': 'Apt. 692',
#    'city': 'South Elvis',
#    'zipcode': '53919-4257',
#    'geo': {'lat': '29.4572', 'lng': '-164.2990'}},
#   'phone': '493-170-9623 x156',
#   'website': 'kale.biz',
#   'company': {'name': 'Robel-Corkery',
#    'catchPhrase': 'Multi-tiered zero tolerance productivity',
#    'bs': 'transition cutting-edge web services'}},
#  {'id': 5,
#   'name': 'Chelsey Dietrich',
#   'username': 'Kamren',
#   'email': 'Lucio_Hettinger@annie.ca',
#   'address': {'street': 'Skiles Walks',
#    'suite': 'Suite 351',
#    'city': 'Roscoeview',
#    'zipcode': '33263',
#    'geo': {'lat': '-31.8129', 'lng': '62.5342'}},
#   'phone': '(254)954-1289',
#   'website': 'demarco.info',
#   'company': {'name': 'Keebler LLC',
#    'catchPhrase': 'User-centric fault-tolerant solution',
#    'bs': 'revolutionize end-to-end systems'}},
#  {'id': 6,
#   'name': 'Mrs. Dennis Schulist',
#   'username': 'Leopoldo_Corkery',
#   'email': 'Karley_Dach@jasper.info',
#   'address': {'street': 'Norberto Crossing',
#    'suite': 'Apt. 950',
#    'city': 'South Christy',
#    'zipcode': '23505-1337',
#    'geo': {'lat': '-71.4197', 'lng': '71.7478'}},
#   'phone': '1-477-935-8478 x6430',
#   'website': 'ola.org',
#   'company': {'name': 'Considine-Lockman',
#    'catchPhrase': 'Synchronised bottom-line interface',
#    'bs': 'e-enable innovative applications'}},
#  {'id': 7,
#   'name': 'Kurtis Weissnat',
#   'username': 'Elwyn.Skiles',
#   'email': 'Telly.Hoeger@billy.biz',
#   'address': {'street': 'Rex Trail',
#    'suite': 'Suite 280',
#    'city': 'Howemouth',
#    'zipcode': '58804-1099',
#    'geo': {'lat': '24.8918', 'lng': '21.8984'}},
#   'phone': '210.067.6132',
#   'website': 'elvis.io',
#   'company': {'name': 'Johns Group',
#    'catchPhrase': 'Configurable multimedia task-force',
#    'bs': 'generate enterprise e-tailers'}},
#  {'id': 8,
#   'name': 'Nicholas Runolfsdottir V',
#   'username': 'Maxime_Nienow',
#   'email': 'Sherwood@rosamond.me',
#   'address': {'street': 'Ellsworth Summit',
#    'suite': 'Suite 729',
#    'city': 'Aliyaview',
#    'zipcode': '45169',
#    'geo': {'lat': '-14.3990', 'lng': '-120.7677'}},
#   'phone': '586.493.6943 x140',
#   'website': 'jacynthe.com',
#   'company': {'name': 'Abernathy Group',
#    'catchPhrase': 'Implemented secondary concept',
#    'bs': 'e-enable extensible e-tailers'}},
#  {'id': 9,
#   'name': 'Glenna Reichert',
#   'username': 'Delphine',
#   'email': 'Chaim_McDermott@dana.io',
#   'address': {'street': 'Dayna Park',
#    'suite': 'Suite 449',
#    'city': 'Bartholomebury',
#    'zipcode': '76495-3109',
#    'geo': {'lat': '24.6463', 'lng': '-168.8889'}},
#   'phone': '(775)976-6794 x41206',
#   'website': 'conrad.com',
#   'company': {'name': 'Yost and Sons',
#    'catchPhrase': 'Switchable contextually-based project',
#    'bs': 'aggregate real-time technologies'}},
#  {'id': 10,
#   'name': 'Clementina DuBuque',
#   'username': 'Moriah.Stanton',
#   'email': 'Rey.Padberg@karina.biz',
#   'address': {'street': 'Kattie Turnpike',
#    'suite': 'Suite 198',
#    'city': 'Lebsackbury',
#    'zipcode': '31428-2261',
#    'geo': {'lat': '-38.2386', 'lng': '57.2232'}},
#   'phone': '024-648-3804',
#   'website': 'ambrose.net',
#   'company': {'name': 'Hoeger LLC',
#    'catchPhrase': 'Centralized empowering task-force',
#    'bs': 'target end-to-end models'}}]

# %% [markdown]
# ### GitHub API - Accessing the data in the JSON
#
# Now that we know
# - what an API is,
# - how to request information from one (requests),
# - how the information will be delivered to us (JSON):
#
# Let's look how we can use this information. We will first look at how we can access particular values within the JSON. Then we will look at a couple of methods to make a dataframe from the JSON.
#
# Github has many APIs. Here we'll look at two of them.

# %%
# Very basic API (a string returned).

# GitHub's Zen API produces a new inspirational phrase every 30 seconds.
# Run this cell again in 30 seconds to see a different output.

resp = requests.get("https://api.github.com/zen")
resp.text
# Out:
# 'Keep it logically awesome.'

# %%
# More complex API (a large json returned).

# Github's Event API shows the events that power the various activity streams on the site.
# In other words, what's happening on Github, who's updating what?

response = requests.get('https://api.github.com/events')
github_response = response.json()
github_response
# Out:
# [{'id': '27028491443',
#   'type': 'PushEvent',
#   'actor': {'id': 4019818,
#    'login': 'eddiewillers',
#    'display_login': 'eddiewillers',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/eddiewillers',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/4019818?'},
#   'repo': {'id': 561198962,
#    'name': 'pow-co/powstream.com',
#    'url': 'https://api.github.com/repos/pow-co/powstream.com'},
#   'payload': {'repository_id': 561198962,
#    'push_id': 12589693234,
#    'size': 4,
#    'distinct_size': 1,
#    'ref': 'refs/heads/master',
#    'head': '6a33e06ee231814b2c4930aaa0390c11f5fef747',
#    'before': '1093dcde575a9c727edc753524da18cf7e96a2a2',
#    'commits': [{'sha': 'e0c8bfd3c1d83462159395e1dd79a9f7a3109f67',
#      'author': {'email': 'derrick@pow.co', 'name': 'Eddie Willers'},
#      'message': 'Fix Broken Logo Image Link\n\nSwitch bitcoinfiles to bico.media',
#      'distinct': False,
#      'url': 'https://api.github.com/repos/pow-co/powstream.com/commits/e0c8bfd3c1d83462159395e1dd79a9f7a3109f67'},
#     {'sha': '6473dbe45215738a6d471111381dfac61c3d3eac',
#      'author': {'email': 'derrick@pow.co', 'name': 'Eddie Willers'},
#      'message': 'Update VideoCard.jsx',
#      'distinct': False,
#      'url': 'https://api.github.com/repos/pow-co/powstream.com/commits/6473dbe45215738a6d471111381dfac61c3d3eac'},
#     {'sha': 'aa21d021f90a56c922a1f662a47e4fcb64f6cb43',
#      'author': {'email': 'derrick@pow.co', 'name': 'Eddie Willers'},
#      'message': 'Dunno',
#      'distinct': False,
#      'url': 'https://api.github.com/repos/pow-co/powstream.com/commits/aa21d021f90a56c922a1f662a47e4fcb64f6cb43'},
#     {'sha': '6a33e06ee231814b2c4930aaa0390c11f5fef747',
#      'author': {'email': 'derrick@pow.co', 'name': 'Eddie Willers'},
#      'message': 'Merge pull request #17 from pow-co/logo\n\nFix Broken Logo Image Link',
#      'distinct': True,
#      'url': 'https://api.github.com/repos/pow-co/powstream.com/commits/6a33e06ee231814b2c4930aaa0390c11f5fef747'}]},
#   'public': True,
#   'created_at': '2023-02-11T22:38:31Z',
#   'org': {'id': 89090814,
#    'login': 'pow-co',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/orgs/pow-co',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/89090814?'}},
#  {'id': '27028491449',
#   'type': 'PushEvent',
#   'actor': {'id': 41898282,
#    'login': 'github-actions[bot]',
#    'display_login': 'github-actions',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/github-actions[bot]',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/41898282?'},
#   'repo': {'id': 457150042,
#    'name': 'Louiz-Ferraz/Louiz-Ferraz',
#    'url': 'https://api.github.com/repos/Louiz-Ferraz/Louiz-Ferraz'},
#   'payload': {'repository_id': 457150042,
#    'push_id': 12589693241,
#    'size': 1,
#    'distinct_size': 1,
#    'ref': 'refs/heads/output',
#    'head': '4001fe85dfb036c1704b27e839c9e16057ff5768',
#    'before': 'a87ceccf10d37cd322f0427a36071564c15dd24b',
#    'commits': [{'sha': '4001fe85dfb036c1704b27e839c9e16057ff5768',
#      'author': {'email': '41898282+github-actions[bot]@users.noreply.github.com',
#       'name': 'github-actions[bot]'},
#      'message': 'Deploy to GitHub pages',
#      'distinct': True,
#      'url': 'https://api.github.com/repos/Louiz-Ferraz/Louiz-Ferraz/commits/4001fe85dfb036c1704b27e839c9e16057ff5768'}]},
#   'public': True,
#   'created_at': '2023-02-11T22:38:31Z'},
#  {'id': '27028491440',
#   'type': 'CreateEvent',
#   'actor': {'id': 105957472,
#    'login': 'nathan2slime',
#    'display_login': 'nathan2slime',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/nathan2slime',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/105957472?'},
#   'repo': {'id': 599342587,
#    'name': 'nathan2slime/spacekrypton',
#    'url': 'https://api.github.com/repos/nathan2slime/spacekrypton'},
#   'payload': {'ref': 'fix/track',
#    'ref_type': 'branch',
#    'master_branch': 'master',
#    'description': 'Real-time tracking of artificial satellites',
#    'pusher_type': 'user'},
#   'public': True,
#   'created_at': '2023-02-11T22:38:31Z'},
#  {'id': '27028491441',
#   'type': 'PushEvent',
#   'actor': {'id': 70250106,
#    'login': 'devereauxk',
#    'display_login': 'devereauxk',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/devereauxk',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/70250106?'},
#   'repo': {'id': 380052777,
#    'name': 'devereauxk/eic_sim_projects',
#    'url': 'https://api.github.com/repos/devereauxk/eic_sim_projects'},
#   'payload': {'repository_id': 380052777,
#    'push_id': 12589693233,
#    'size': 1,
#    'distinct_size': 1,
#    'ref': 'refs/heads/master',
#    'head': '897039df493f2b941e3ad17f106a711e4d2658c4',
#    'before': 'a325c3b52cd0fc3dc7ffe0f1797fd38e09ed67a4',
#    'commits': [{'sha': '897039df493f2b941e3ad17f106a711e4d2658c4',
#      'author': {'email': 'devereauxk@berkeley.edu', 'name': 'Kyle Devereaux'},
#      'message': 'emergenecy calculations ep eHIJING vs pythia',
#      'distinct': True,
#      'url': 'https://api.github.com/repos/devereauxk/eic_sim_projects/commits/897039df493f2b941e3ad17f106a711e4d2658c4'}]},
#   'public': True,
#   'created_at': '2023-02-11T22:38:31Z'},
#  {'id': '27028491439',
#   'type': 'PushEvent',
#   'actor': {'id': 97152724,
#    'login': 'diegoarauj0',
#    'display_login': 'diegoarauj0',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/diegoarauj0',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/97152724?'},
#   'repo': {'id': 597862056,
#    'name': 'diegoarauj0/PokeDex',
#    'url': 'https://api.github.com/repos/diegoarauj0/PokeDex'},
#   'payload': {'repository_id': 597862056,
#    'push_id': 12589693232,
#    'size': 1,
#    'distinct_size': 1,
#    'ref': 'refs/heads/main',
#    'head': '0edd76d7b94547de3f72af23feff2f369736d735',
#    'before': '00c09b105293736a1cb086f125bfe4e32268ddfd',
#    'commits': [{'sha': '0edd76d7b94547de3f72af23feff2f369736d735',
#      'author': {'email': '97152724+diegoarauj0@users.noreply.github.com',
#       'name': 'Diego Araujo'},
#      'message': 'TypeScript - RendererHtml\n\nArumando div da Evolução view',
#      'distinct': True,
#      'url': 'https://api.github.com/repos/diegoarauj0/PokeDex/commits/0edd76d7b94547de3f72af23feff2f369736d735'}]},
#   'public': True,
#   'created_at': '2023-02-11T22:38:31Z'},
#  {'id': '27028491431',
#   'type': 'PushEvent',
#   'actor': {'id': 43733305,
#    'login': 'yanonono',
#    'display_login': 'yanonono',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/yanonono',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/43733305?'},
#   'repo': {'id': 183440182,
#    'name': 'yanonono/booth-update',
#    'url': 'https://api.github.com/repos/yanonono/booth-update'},
#   'payload': {'repository_id': 183440182,
#    'push_id': 12589693229,
#    'size': 1,
#    'distinct_size': 1,
#    'ref': 'refs/heads/master',
#    'head': '53fa5187401e546bff9b53f63ea76d44d09c8597',
#    'before': '2968586cf3b75f3d8b06c82225d7b043664b4984',
#    'commits': [{'sha': '53fa5187401e546bff9b53f63ea76d44d09c8597',
#      'author': {'email': 'yano.nono.0701+booth-github@gmail.com',
#       'name': 'yano.nono'},
#      'message': 'updated at: 2023-02-12 07:38, CSToon Shader〔v1.0.4〕 - CS_INDUSTRIAL - BOOTH',
#      'distinct': True,
#      'url': 'https://api.github.com/repos/yanonono/booth-update/commits/53fa5187401e546bff9b53f63ea76d44d09c8597'}]},
#   'public': True,
#   'created_at': '2023-02-11T22:38:31Z'},
#  {'id': '27028491422',
#   'type': 'CreateEvent',
#   'actor': {'id': 15019905,
#    'login': 'mikle-viter',
#    'display_login': 'mikle-viter',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/mikle-viter',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/15019905?'},
#   'repo': {'id': 584455711,
#    'name': 'mikle-viter/data_processing_methods',
#    'url': 'https://api.github.com/repos/mikle-viter/data_processing_methods'},
#   'payload': {'ref': 'Lesson_8',
#    'ref_type': 'branch',
#    'master_branch': 'master',
#    'description': None,
#    'pusher_type': 'user'},
#   'public': True,
#   'created_at': '2023-02-11T22:38:31Z'},
#  {'id': '27028491438',
#   'type': 'IssuesEvent',
#   'actor': {'id': 96301800,
#    'login': 'AjayMaheshwari23',
#    'display_login': 'AjayMaheshwari23',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/AjayMaheshwari23',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/96301800?'},
#   'repo': {'id': 350087687,
#    'name': 'PalisadoesFoundation/talawa-admin',
#    'url': 'https://api.github.com/repos/PalisadoesFoundation/talawa-admin'},
#   'payload': {'action': 'opened',
#    'issue': {'url': 'https://api.github.com/repos/PalisadoesFoundation/talawa-admin/issues/471',
#     'repository_url': 'https://api.github.com/repos/PalisadoesFoundation/talawa-admin',
#     'labels_url': 'https://api.github.com/repos/PalisadoesFoundation/talawa-admin/issues/471/labels{/name}',
#     'comments_url': 'https://api.github.com/repos/PalisadoesFoundation/talawa-admin/issues/471/comments',
#     'events_url': 'https://api.github.com/repos/PalisadoesFoundation/talawa-admin/issues/471/events',
#     'html_url': 'https://github.com/PalisadoesFoundation/talawa-admin/issues/471',
#     'id': 1581039570,
#     'node_id': 'I_kwDOFN3qB85ePL_S',
#     'number': 471,
#     'title': 'Removing DOMNesting Error',
#     'user': {'login': 'AjayMaheshwari23',
#      'id': 96301800,
#      'node_id': 'U_kgDOBb1y6A',
#      'avatar_url': 'https://avatars.githubusercontent.com/u/96301800?v=4',
#      'gravatar_id': '',
#      'url': 'https://api.github.com/users/AjayMaheshwari23',
#      'html_url': 'https://github.com/AjayMaheshwari23',
#      'followers_url': 'https://api.github.com/users/AjayMaheshwari23/followers',
#      'following_url': 'https://api.github.com/users/AjayMaheshwari23/following{/other_user}',
#      'gists_url': 'https://api.github.com/users/AjayMaheshwari23/gists{/gist_id}',
#      'starred_url': 'https://api.github.com/users/AjayMaheshwari23/starred{/owner}{/repo}',
#      'subscriptions_url': 'https://api.github.com/users/AjayMaheshwari23/subscriptions',
#      'organizations_url': 'https://api.github.com/users/AjayMaheshwari23/orgs',
#      'repos_url': 'https://api.github.com/users/AjayMaheshwari23/repos',
#      'events_url': 'https://api.github.com/users/AjayMaheshwari23/events{/privacy}',
#      'received_events_url': 'https://api.github.com/users/AjayMaheshwari23/received_events',
#      'type': 'User',
#      'site_admin': False},
#     'labels': [{'id': 2843026162,
#       'node_id': 'MDU6TGFiZWwyODQzMDI2MTYy',
#       'url': 'https://api.github.com/repos/PalisadoesFoundation/talawa-admin/labels/bug',
#       'name': 'bug',
#       'color': 'd73a4a',
#       'default': True,
#       'description': "Something isn't working"}],
#     'state': 'open',
#     'locked': False,
#     'assignee': None,
#     'assignees': [],
#     'milestone': None,
#     'comments': 0,
#     'created_at': '2023-02-11T22:38:31Z',
#     'updated_at': '2023-02-11T22:38:31Z',
#     'closed_at': None,
#     'author_association': 'CONTRIBUTOR',
#     'active_lock_reason': None,
#     'body': '**Bug**\r\nIn the organisation list page, DOMNesting is not done properly , I would like to remove this error.\r\n\r\n**Expected behavior**\r\nError Free console\r\n\r\n**Actual behavior**\r\nvalidateDOMNesting(...) Error\r\n\r\n**Screenshots**\r\n<img width="1440" alt="Screenshot 2023-02-12 at 2 43 29 AM" src="https://user-images.githubusercontent.com/96301800/218283963-b8edd148-1c41-4c5a-9652-4ab1aaafbd5d.png">\r\n\r\nCan I work on this issue ?\r\n',
#     'reactions': {'url': 'https://api.github.com/repos/PalisadoesFoundation/talawa-admin/issues/471/reactions',
#      'total_count': 0,
#      '+1': 0,
#      '-1': 0,
#      'laugh': 0,
#      'hooray': 0,
#      'confused': 0,
#      'heart': 0,
#      'rocket': 0,
#      'eyes': 0},
#     'timeline_url': 'https://api.github.com/repos/PalisadoesFoundation/talawa-admin/issues/471/timeline',
#     'performed_via_github_app': None,
#     'state_reason': None}},
#   'public': True,
#   'created_at': '2023-02-11T22:38:31Z',
#   'org': {'id': 24500036,
#    'login': 'PalisadoesFoundation',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/orgs/PalisadoesFoundation',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/24500036?'}},
#  {'id': '27028491434',
#   'type': 'DeleteEvent',
#   'actor': {'id': 71354125,
#    'login': 'aws-connector-for-github[bot]',
#    'display_login': 'aws-connector-for-github',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/aws-connector-for-github[bot]',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/71354125?'},
#   'repo': {'id': 429551228,
#    'name': 'bullet-dev-team/python-pyramid-public',
#    'url': 'https://api.github.com/repos/bullet-dev-team/python-pyramid-public'},
#   'payload': {'ref': 'cicd-e2e-ofl6bd',
#    'ref_type': 'branch',
#    'pusher_type': 'user'},
#   'public': True,
#   'created_at': '2023-02-11T22:38:31Z'},
#  {'id': '27028491425',
#   'type': 'PushEvent',
#   'actor': {'id': 107641357,
#    'login': 'MccMiles',
#    'display_login': 'MccMiles',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/MccMiles',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/107641357?'},
#   'repo': {'id': 595916083,
#    'name': 'MccMiles/AirBnB',
#    'url': 'https://api.github.com/repos/MccMiles/AirBnB'},
#   'payload': {'repository_id': 595916083,
#    'push_id': 12589693228,
#    'size': 1,
#    'distinct_size': 1,
#    'ref': 'refs/heads/dev',
#    'head': 'dca91bf5f257e6be83b040b93f65aa098d99e98c',
#    'before': '818c594ab9861517516ae0877ca567cc51052d9a',
#    'commits': [{'sha': 'dca91bf5f257e6be83b040b93f65aa098d99e98c',
#      'author': {'email': '107641357+MccMiles@users.noreply.github.com',
#       'name': 'MccMiles'},
#      'message': 'npmi',
#      'distinct': True,
#      'url': 'https://api.github.com/repos/MccMiles/AirBnB/commits/dca91bf5f257e6be83b040b93f65aa098d99e98c'}]},
#   'public': True,
#   'created_at': '2023-02-11T22:38:31Z'},
#  {'id': '27028491421',
#   'type': 'CreateEvent',
#   'actor': {'id': 41898282,
#    'login': 'github-actions[bot]',
#    'display_login': 'github-actions',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/github-actions[bot]',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/41898282?'},
#   'repo': {'id': 388872173,
#    'name': 'gear-tech/gear',
#    'url': 'https://api.github.com/repos/gear-tech/gear'},
#   'payload': {'ref': 'build',
#    'ref_type': 'tag',
#    'master_branch': 'master',
#    'description': 'Computational Component of Polkadot Network',
#    'pusher_type': 'user'},
#   'public': True,
#   'created_at': '2023-02-11T22:38:31Z',
#   'org': {'id': 72395063,
#    'login': 'gear-tech',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/orgs/gear-tech',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/72395063?'}},
#  {'id': '27028491415',
#   'type': 'CreateEvent',
#   'actor': {'id': 110985398,
#    'login': 'marcgirbaub',
#    'display_login': 'marcgirbaub',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/marcgirbaub',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/110985398?'},
#   'repo': {'id': 595722337,
#    'name': 'isdi-coders-2023/Payasos-Ocurrentes-202301-bcn',
#    'url': 'https://api.github.com/repos/isdi-coders-2023/Payasos-Ocurrentes-202301-bcn'},
#   'payload': {'ref': 'feature/test-getSingleCharacter',
#    'ref_type': 'branch',
#    'master_branch': 'main',
#    'description': None,
#    'pusher_type': 'user'},
#   'public': True,
#   'created_at': '2023-02-11T22:38:31Z',
#   'org': {'id': 120566616,
#    'login': 'isdi-coders-2023',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/orgs/isdi-coders-2023',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/120566616?'}},
#  {'id': '27028491419',
#   'type': 'WatchEvent',
#   'actor': {'id': 5899823,
#    'login': 'Saloframes',
#    'display_login': 'Saloframes',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/Saloframes',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/5899823?'},
#   'repo': {'id': 345346677,
#    'name': 'NeoApplications/Neo-Store',
#    'url': 'https://api.github.com/repos/NeoApplications/Neo-Store'},
#   'payload': {'action': 'started'},
#   'public': True,
#   'created_at': '2023-02-11T22:38:31Z',
#   'org': {'id': 101910870,
#    'login': 'NeoApplications',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/orgs/NeoApplications',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/101910870?'}},
#  {'id': '27028491399',
#   'type': 'PullRequestEvent',
#   'actor': {'id': 4019818,
#    'login': 'eddiewillers',
#    'display_login': 'eddiewillers',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/eddiewillers',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/4019818?'},
#   'repo': {'id': 561198962,
#    'name': 'pow-co/powstream.com',
#    'url': 'https://api.github.com/repos/pow-co/powstream.com'},
#   'payload': {'action': 'closed',
#    'number': 17,
#    'pull_request': {'url': 'https://api.github.com/repos/pow-co/powstream.com/pulls/17',
#     'id': 1220690515,
#     'node_id': 'PR_kwDOIXM3cs5IwkJT',
#     'html_url': 'https://github.com/pow-co/powstream.com/pull/17',
#     'diff_url': 'https://github.com/pow-co/powstream.com/pull/17.diff',
#     'patch_url': 'https://github.com/pow-co/powstream.com/pull/17.patch',
#     'issue_url': 'https://api.github.com/repos/pow-co/powstream.com/issues/17',
#     'number': 17,
#     'state': 'closed',
#     'locked': False,
#     'title': 'Fix Broken Logo Image Link',
#     'user': {'login': 'eddiewillers',
#      'id': 4019818,
#      'node_id': 'MDQ6VXNlcjQwMTk4MTg=',
#      'avatar_url': 'https://avatars.githubusercontent.com/u/4019818?v=4',
#      'gravatar_id': '',
#      'url': 'https://api.github.com/users/eddiewillers',
#      'html_url': 'https://github.com/eddiewillers',
#      'followers_url': 'https://api.github.com/users/eddiewillers/followers',
#      'following_url': 'https://api.github.com/users/eddiewillers/following{/other_user}',
#      'gists_url': 'https://api.github.com/users/eddiewillers/gists{/gist_id}',
#      'starred_url': 'https://api.github.com/users/eddiewillers/starred{/owner}{/repo}',
#      'subscriptions_url': 'https://api.github.com/users/eddiewillers/subscriptions',
#      'organizations_url': 'https://api.github.com/users/eddiewillers/orgs',
#      'repos_url': 'https://api.github.com/users/eddiewillers/repos',
#      'events_url': 'https://api.github.com/users/eddiewillers/events{/privacy}',
#      'received_events_url': 'https://api.github.com/users/eddiewillers/received_events',
#      'type': 'User',
#      'site_admin': False},
#     'body': 'Switch bitcoinfiles to bico.media',
#     'created_at': '2023-01-29T16:36:06Z',
#     'updated_at': '2023-02-11T22:38:30Z',
#     'closed_at': '2023-02-11T22:38:30Z',
#     'merged_at': '2023-02-11T22:38:30Z',
#     'merge_commit_sha': '6a33e06ee231814b2c4930aaa0390c11f5fef747',
#     'assignee': None,
#     'assignees': [],
#     'requested_reviewers': [{'login': 'owenkellogg',
#       'id': 508282,
#       'node_id': 'MDQ6VXNlcjUwODI4Mg==',
#       'avatar_url': 'https://avatars.githubusercontent.com/u/508282?v=4',
#       'gravatar_id': '',
#       'url': 'https://api.github.com/users/owenkellogg',
#       'html_url': 'https://github.com/owenkellogg',
#       'followers_url': 'https://api.github.com/users/owenkellogg/followers',
#       'following_url': 'https://api.github.com/users/owenkellogg/following{/other_user}',
#       'gists_url': 'https://api.github.com/users/owenkellogg/gists{/gist_id}',
#       'starred_url': 'https://api.github.com/users/owenkellogg/starred{/owner}{/repo}',
#       'subscriptions_url': 'https://api.github.com/users/owenkellogg/subscriptions',
#       'organizations_url': 'https://api.github.com/users/owenkellogg/orgs',
#       'repos_url': 'https://api.github.com/users/owenkellogg/repos',
#       'events_url': 'https://api.github.com/users/owenkellogg/events{/privacy}',
#       'received_events_url': 'https://api.github.com/users/owenkellogg/received_events',
#       'type': 'User',
#       'site_admin': False}],
#     'requested_teams': [],
#     'labels': [],
#     'milestone': None,
#     'draft': False,
#     'commits_url': 'https://api.github.com/repos/pow-co/powstream.com/pulls/17/commits',
#     'review_comments_url': 'https://api.github.com/repos/pow-co/powstream.com/pulls/17/comments',
#     'review_comment_url': 'https://api.github.com/repos/pow-co/powstream.com/pulls/comments{/number}',
#     'comments_url': 'https://api.github.com/repos/pow-co/powstream.com/issues/17/comments',
#     'statuses_url': 'https://api.github.com/repos/pow-co/powstream.com/statuses/aa21d021f90a56c922a1f662a47e4fcb64f6cb43',
#     'head': {'label': 'pow-co:logo',
#      'ref': 'logo',
#      'sha': 'aa21d021f90a56c922a1f662a47e4fcb64f6cb43',
#      'user': {'login': 'pow-co',
#       'id': 89090814,
#       'node_id': 'MDEyOk9yZ2FuaXphdGlvbjg5MDkwODE0',
#       'avatar_url': 'https://avatars.githubusercontent.com/u/89090814?v=4',
#       'gravatar_id': '',
#       'url': 'https://api.github.com/users/pow-co',
#       'html_url': 'https://github.com/pow-co',
#       'followers_url': 'https://api.github.com/users/pow-co/followers',
#       'following_url': 'https://api.github.com/users/pow-co/following{/other_user}',
#       'gists_url': 'https://api.github.com/users/pow-co/gists{/gist_id}',
#       'starred_url': 'https://api.github.com/users/pow-co/starred{/owner}{/repo}',
#       'subscriptions_url': 'https://api.github.com/users/pow-co/subscriptions',
#       'organizations_url': 'https://api.github.com/users/pow-co/orgs',
#       'repos_url': 'https://api.github.com/users/pow-co/repos',
#       'events_url': 'https://api.github.com/users/pow-co/events{/privacy}',
#       'received_events_url': 'https://api.github.com/users/pow-co/received_events',
#       'type': 'Organization',
#       'site_admin': False},
#      'repo': {'id': 561198962,
#       'node_id': 'R_kgDOIXM3cg',
#       'name': 'powstream.com',
#       'full_name': 'pow-co/powstream.com',
#       'private': False,
#       'owner': {'login': 'pow-co',
#        'id': 89090814,
#        'node_id': 'MDEyOk9yZ2FuaXphdGlvbjg5MDkwODE0',
#        'avatar_url': 'https://avatars.githubusercontent.com/u/89090814?v=4',
#        'gravatar_id': '',
#        'url': 'https://api.github.com/users/pow-co',
#        'html_url': 'https://github.com/pow-co',
#        'followers_url': 'https://api.github.com/users/pow-co/followers',
#        'following_url': 'https://api.github.com/users/pow-co/following{/other_user}',
#        'gists_url': 'https://api.github.com/users/pow-co/gists{/gist_id}',
#        'starred_url': 'https://api.github.com/users/pow-co/starred{/owner}{/repo}',
#        'subscriptions_url': 'https://api.github.com/users/pow-co/subscriptions',
#        'organizations_url': 'https://api.github.com/users/pow-co/orgs',
#        'repos_url': 'https://api.github.com/users/pow-co/repos',
#        'events_url': 'https://api.github.com/users/pow-co/events{/privacy}',
#        'received_events_url': 'https://api.github.com/users/pow-co/received_events',
#        'type': 'Organization',
#        'site_admin': False},
#       'html_url': 'https://github.com/pow-co/powstream.com',
#       'description': None,
#       'fork': False,
#       'url': 'https://api.github.com/repos/pow-co/powstream.com',
#       'forks_url': 'https://api.github.com/repos/pow-co/powstream.com/forks',
#       'keys_url': 'https://api.github.com/repos/pow-co/powstream.com/keys{/key_id}',
#       'collaborators_url': 'https://api.github.com/repos/pow-co/powstream.com/collaborators{/collaborator}',
#       'teams_url': 'https://api.github.com/repos/pow-co/powstream.com/teams',
#       'hooks_url': 'https://api.github.com/repos/pow-co/powstream.com/hooks',
#       'issue_events_url': 'https://api.github.com/repos/pow-co/powstream.com/issues/events{/number}',
#       'events_url': 'https://api.github.com/repos/pow-co/powstream.com/events',
#       'assignees_url': 'https://api.github.com/repos/pow-co/powstream.com/assignees{/user}',
#       'branches_url': 'https://api.github.com/repos/pow-co/powstream.com/branches{/branch}',
#       'tags_url': 'https://api.github.com/repos/pow-co/powstream.com/tags',
#       'blobs_url': 'https://api.github.com/repos/pow-co/powstream.com/git/blobs{/sha}',
#       'git_tags_url': 'https://api.github.com/repos/pow-co/powstream.com/git/tags{/sha}',
#       'git_refs_url': 'https://api.github.com/repos/pow-co/powstream.com/git/refs{/sha}',
#       'trees_url': 'https://api.github.com/repos/pow-co/powstream.com/git/trees{/sha}',
#       'statuses_url': 'https://api.github.com/repos/pow-co/powstream.com/statuses/{sha}',
#       'languages_url': 'https://api.github.com/repos/pow-co/powstream.com/languages',
#       'stargazers_url': 'https://api.github.com/repos/pow-co/powstream.com/stargazers',
#       'contributors_url': 'https://api.github.com/repos/pow-co/powstream.com/contributors',
#       'subscribers_url': 'https://api.github.com/repos/pow-co/powstream.com/subscribers',
#       'subscription_url': 'https://api.github.com/repos/pow-co/powstream.com/subscription',
#       'commits_url': 'https://api.github.com/repos/pow-co/powstream.com/commits{/sha}',
#       'git_commits_url': 'https://api.github.com/repos/pow-co/powstream.com/git/commits{/sha}',
#       'comments_url': 'https://api.github.com/repos/pow-co/powstream.com/comments{/number}',
#       'issue_comment_url': 'https://api.github.com/repos/pow-co/powstream.com/issues/comments{/number}',
#       'contents_url': 'https://api.github.com/repos/pow-co/powstream.com/contents/{+path}',
#       'compare_url': 'https://api.github.com/repos/pow-co/powstream.com/compare/{base}...{head}',
#       'merges_url': 'https://api.github.com/repos/pow-co/powstream.com/merges',
#       'archive_url': 'https://api.github.com/repos/pow-co/powstream.com/{archive_format}{/ref}',
#       'downloads_url': 'https://api.github.com/repos/pow-co/powstream.com/downloads',
#       'issues_url': 'https://api.github.com/repos/pow-co/powstream.com/issues{/number}',
#       'pulls_url': 'https://api.github.com/repos/pow-co/powstream.com/pulls{/number}',
#       'milestones_url': 'https://api.github.com/repos/pow-co/powstream.com/milestones{/number}',
#       'notifications_url': 'https://api.github.com/repos/pow-co/powstream.com/notifications{?since,all,participating}',
#       'labels_url': 'https://api.github.com/repos/pow-co/powstream.com/labels{/name}',
#       'releases_url': 'https://api.github.com/repos/pow-co/powstream.com/releases{/id}',
#       'deployments_url': 'https://api.github.com/repos/pow-co/powstream.com/deployments',
#       'created_at': '2022-11-03T07:00:23Z',
#       'updated_at': '2022-12-04T00:52:44Z',
#       'pushed_at': '2023-02-11T22:38:30Z',
#       'git_url': 'git://github.com/pow-co/powstream.com.git',
#       'ssh_url': 'git@github.com:pow-co/powstream.com.git',
#       'clone_url': 'https://github.com/pow-co/powstream.com.git',
#       'svn_url': 'https://github.com/pow-co/powstream.com',
#       'homepage': None,
#       'size': 1333,
#       'stargazers_count': 1,
#       'watchers_count': 1,
#       'language': 'JavaScript',
#       'has_issues': True,
#       'has_projects': True,
#       'has_downloads': True,
#       'has_wiki': True,
#       'has_pages': False,
#       'has_discussions': False,
#       'forks_count': 0,
#       'mirror_url': None,
#       'archived': False,
#       'disabled': False,
#       'open_issues_count': 14,
#       'license': None,
#       'allow_forking': True,
#       'is_template': False,
#       'web_commit_signoff_required': False,
#       'topics': [],
#       'visibility': 'public',
#       'forks': 0,
#       'open_issues': 14,
#       'watchers': 1,
#       'default_branch': 'master'}},
#     'base': {'label': 'pow-co:master',
#      'ref': 'master',
#      'sha': '1093dcde575a9c727edc753524da18cf7e96a2a2',
#      'user': {'login': 'pow-co',
#       'id': 89090814,
#       'node_id': 'MDEyOk9yZ2FuaXphdGlvbjg5MDkwODE0',
#       'avatar_url': 'https://avatars.githubusercontent.com/u/89090814?v=4',
#       'gravatar_id': '',
#       'url': 'https://api.github.com/users/pow-co',
#       'html_url': 'https://github.com/pow-co',
#       'followers_url': 'https://api.github.com/users/pow-co/followers',
#       'following_url': 'https://api.github.com/users/pow-co/following{/other_user}',
#       'gists_url': 'https://api.github.com/users/pow-co/gists{/gist_id}',
#       'starred_url': 'https://api.github.com/users/pow-co/starred{/owner}{/repo}',
#       'subscriptions_url': 'https://api.github.com/users/pow-co/subscriptions',
#       'organizations_url': 'https://api.github.com/users/pow-co/orgs',
#       'repos_url': 'https://api.github.com/users/pow-co/repos',
#       'events_url': 'https://api.github.com/users/pow-co/events{/privacy}',
#       'received_events_url': 'https://api.github.com/users/pow-co/received_events',
#       'type': 'Organization',
#       'site_admin': False},
#      'repo': {'id': 561198962,
#       'node_id': 'R_kgDOIXM3cg',
#       'name': 'powstream.com',
#       'full_name': 'pow-co/powstream.com',
#       'private': False,
#       'owner': {'login': 'pow-co',
#        'id': 89090814,
#        'node_id': 'MDEyOk9yZ2FuaXphdGlvbjg5MDkwODE0',
#        'avatar_url': 'https://avatars.githubusercontent.com/u/89090814?v=4',
#        'gravatar_id': '',
#        'url': 'https://api.github.com/users/pow-co',
#        'html_url': 'https://github.com/pow-co',
#        'followers_url': 'https://api.github.com/users/pow-co/followers',
#        'following_url': 'https://api.github.com/users/pow-co/following{/other_user}',
#        'gists_url': 'https://api.github.com/users/pow-co/gists{/gist_id}',
#        'starred_url': 'https://api.github.com/users/pow-co/starred{/owner}{/repo}',
#        'subscriptions_url': 'https://api.github.com/users/pow-co/subscriptions',
#        'organizations_url': 'https://api.github.com/users/pow-co/orgs',
#        'repos_url': 'https://api.github.com/users/pow-co/repos',
#        'events_url': 'https://api.github.com/users/pow-co/events{/privacy}',
#        'received_events_url': 'https://api.github.com/users/pow-co/received_events',
#        'type': 'Organization',
#        'site_admin': False},
#       'html_url': 'https://github.com/pow-co/powstream.com',
#       'description': None,
#       'fork': False,
#       'url': 'https://api.github.com/repos/pow-co/powstream.com',
#       'forks_url': 'https://api.github.com/repos/pow-co/powstream.com/forks',
#       'keys_url': 'https://api.github.com/repos/pow-co/powstream.com/keys{/key_id}',
#       'collaborators_url': 'https://api.github.com/repos/pow-co/powstream.com/collaborators{/collaborator}',
#       'teams_url': 'https://api.github.com/repos/pow-co/powstream.com/teams',
#       'hooks_url': 'https://api.github.com/repos/pow-co/powstream.com/hooks',
#       'issue_events_url': 'https://api.github.com/repos/pow-co/powstream.com/issues/events{/number}',
#       'events_url': 'https://api.github.com/repos/pow-co/powstream.com/events',
#       'assignees_url': 'https://api.github.com/repos/pow-co/powstream.com/assignees{/user}',
#       'branches_url': 'https://api.github.com/repos/pow-co/powstream.com/branches{/branch}',
#       'tags_url': 'https://api.github.com/repos/pow-co/powstream.com/tags',
#       'blobs_url': 'https://api.github.com/repos/pow-co/powstream.com/git/blobs{/sha}',
#       'git_tags_url': 'https://api.github.com/repos/pow-co/powstream.com/git/tags{/sha}',
#       'git_refs_url': 'https://api.github.com/repos/pow-co/powstream.com/git/refs{/sha}',
#       'trees_url': 'https://api.github.com/repos/pow-co/powstream.com/git/trees{/sha}',
#       'statuses_url': 'https://api.github.com/repos/pow-co/powstream.com/statuses/{sha}',
#       'languages_url': 'https://api.github.com/repos/pow-co/powstream.com/languages',
#       'stargazers_url': 'https://api.github.com/repos/pow-co/powstream.com/stargazers',
#       'contributors_url': 'https://api.github.com/repos/pow-co/powstream.com/contributors',
#       'subscribers_url': 'https://api.github.com/repos/pow-co/powstream.com/subscribers',
#       'subscription_url': 'https://api.github.com/repos/pow-co/powstream.com/subscription',
#       'commits_url': 'https://api.github.com/repos/pow-co/powstream.com/commits{/sha}',
#       'git_commits_url': 'https://api.github.com/repos/pow-co/powstream.com/git/commits{/sha}',
#       'comments_url': 'https://api.github.com/repos/pow-co/powstream.com/comments{/number}',
#       'issue_comment_url': 'https://api.github.com/repos/pow-co/powstream.com/issues/comments{/number}',
#       'contents_url': 'https://api.github.com/repos/pow-co/powstream.com/contents/{+path}',
#       'compare_url': 'https://api.github.com/repos/pow-co/powstream.com/compare/{base}...{head}',
#       'merges_url': 'https://api.github.com/repos/pow-co/powstream.com/merges',
#       'archive_url': 'https://api.github.com/repos/pow-co/powstream.com/{archive_format}{/ref}',
#       'downloads_url': 'https://api.github.com/repos/pow-co/powstream.com/downloads',
#       'issues_url': 'https://api.github.com/repos/pow-co/powstream.com/issues{/number}',
#       'pulls_url': 'https://api.github.com/repos/pow-co/powstream.com/pulls{/number}',
#       'milestones_url': 'https://api.github.com/repos/pow-co/powstream.com/milestones{/number}',
#       'notifications_url': 'https://api.github.com/repos/pow-co/powstream.com/notifications{?since,all,participating}',
#       'labels_url': 'https://api.github.com/repos/pow-co/powstream.com/labels{/name}',
#       'releases_url': 'https://api.github.com/repos/pow-co/powstream.com/releases{/id}',
#       'deployments_url': 'https://api.github.com/repos/pow-co/powstream.com/deployments',
#       'created_at': '2022-11-03T07:00:23Z',
#       'updated_at': '2022-12-04T00:52:44Z',
#       'pushed_at': '2023-02-11T22:38:30Z',
#       'git_url': 'git://github.com/pow-co/powstream.com.git',
#       'ssh_url': 'git@github.com:pow-co/powstream.com.git',
#       'clone_url': 'https://github.com/pow-co/powstream.com.git',
#       'svn_url': 'https://github.com/pow-co/powstream.com',
#       'homepage': None,
#       'size': 1333,
#       'stargazers_count': 1,
#       'watchers_count': 1,
#       'language': 'JavaScript',
#       'has_issues': True,
#       'has_projects': True,
#       'has_downloads': True,
#       'has_wiki': True,
#       'has_pages': False,
#       'has_discussions': False,
#       'forks_count': 0,
#       'mirror_url': None,
#       'archived': False,
#       'disabled': False,
#       'open_issues_count': 14,
#       'license': None,
#       'allow_forking': True,
#       'is_template': False,
#       'web_commit_signoff_required': False,
#       'topics': [],
#       'visibility': 'public',
#       'forks': 0,
#       'open_issues': 14,
#       'watchers': 1,
#       'default_branch': 'master'}},
#     '_links': {'self': {'href': 'https://api.github.com/repos/pow-co/powstream.com/pulls/17'},
#      'html': {'href': 'https://github.com/pow-co/powstream.com/pull/17'},
#      'issue': {'href': 'https://api.github.com/repos/pow-co/powstream.com/issues/17'},
#      'comments': {'href': 'https://api.github.com/repos/pow-co/powstream.com/issues/17/comments'},
#      'review_comments': {'href': 'https://api.github.com/repos/pow-co/powstream.com/pulls/17/comments'},
#      'review_comment': {'href': 'https://api.github.com/repos/pow-co/powstream.com/pulls/comments{/number}'},
#      'commits': {'href': 'https://api.github.com/repos/pow-co/powstream.com/pulls/17/commits'},
#      'statuses': {'href': 'https://api.github.com/repos/pow-co/powstream.com/statuses/aa21d021f90a56c922a1f662a47e4fcb64f6cb43'}},
#     'author_association': 'COLLABORATOR',
#     'auto_merge': None,
#     'active_lock_reason': None,
#     'merged': True,
#     'mergeable': None,
#     'rebaseable': None,
#     'mergeable_state': 'unknown',
#     'merged_by': {'login': 'eddiewillers',
#      'id': 4019818,
#      'node_id': 'MDQ6VXNlcjQwMTk4MTg=',
#      'avatar_url': 'https://avatars.githubusercontent.com/u/4019818?v=4',
#      'gravatar_id': '',
#      'url': 'https://api.github.com/users/eddiewillers',
#      'html_url': 'https://github.com/eddiewillers',
#      'followers_url': 'https://api.github.com/users/eddiewillers/followers',
#      'following_url': 'https://api.github.com/users/eddiewillers/following{/other_user}',
#      'gists_url': 'https://api.github.com/users/eddiewillers/gists{/gist_id}',
#      'starred_url': 'https://api.github.com/users/eddiewillers/starred{/owner}{/repo}',
#      'subscriptions_url': 'https://api.github.com/users/eddiewillers/subscriptions',
#      'organizations_url': 'https://api.github.com/users/eddiewillers/orgs',
#      'repos_url': 'https://api.github.com/users/eddiewillers/repos',
#      'events_url': 'https://api.github.com/users/eddiewillers/events{/privacy}',
#      'received_events_url': 'https://api.github.com/users/eddiewillers/received_events',
#      'type': 'User',
#      'site_admin': False},
#     'comments': 2,
#     'review_comments': 0,
#     'maintainer_can_modify': False,
#     'commits': 3,
#     'additions': 3146,
#     'deletions': 46,
#     'changed_files': 5}},
#   'public': True,
#   'created_at': '2023-02-11T22:38:31Z',
#   'org': {'id': 89090814,
#    'login': 'pow-co',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/orgs/pow-co',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/89090814?'}},
#  {'id': '27028491411',
#   'type': 'CreateEvent',
#   'actor': {'id': 10810283,
#    'login': 'direwolf-github',
#    'display_login': 'direwolf-github',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/direwolf-github',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/10810283?'},
#   'repo': {'id': 600572699,
#    'name': 'direwolf-github/ephemeral-ci-62a0c355',
#    'url': 'https://api.github.com/repos/direwolf-github/ephemeral-ci-62a0c355'},
#   'payload': {'ref': None,
#    'ref_type': 'repository',
#    'master_branch': 'main',
#    'description': None,
#    'pusher_type': 'user'},
#   'public': True,
#   'created_at': '2023-02-11T22:38:31Z'},
#  {'id': '27028491403',
#   'type': 'WatchEvent',
#   'actor': {'id': 110000273,
#    'login': 'jasg27',
#    'display_login': 'jasg27',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/jasg27',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/110000273?'},
#   'repo': {'id': 4165675,
#    'name': 'smicallef/spiderfoot',
#    'url': 'https://api.github.com/repos/smicallef/spiderfoot'},
#   'payload': {'action': 'started'},
#   'public': True,
#   'created_at': '2023-02-11T22:38:31Z'},
#  {'id': '27028491407',
#   'type': 'PushEvent',
#   'actor': {'id': 92614482,
#    'login': 'davidstephenson8',
#    'display_login': 'davidstephenson8',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/davidstephenson8',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/92614482?'},
#   'repo': {'id': 593865644,
#    'name': 'davidstephenson8/Ruby_109',
#    'url': 'https://api.github.com/repos/davidstephenson8/Ruby_109'},
#   'payload': {'repository_id': 593865644,
#    'push_id': 12589693219,
#    'size': 1,
#    'distinct_size': 1,
#    'ref': 'refs/heads/main',
#    'head': '1a435e315ecc399bdbe15bda866df4657104110d',
#    'before': '0c266b3585b294d921dd7597eed7d61c8aed4bd7',
#    'commits': [{'sha': '1a435e315ecc399bdbe15bda866df4657104110d',
#      'author': {'email': 'davidstephenson8@gmail.com',
#       'name': 'David Stephenson'},
#      'message': 'Some practice problems to make sure I still know how to code',
#      'distinct': True,
#      'url': 'https://api.github.com/repos/davidstephenson8/Ruby_109/commits/1a435e315ecc399bdbe15bda866df4657104110d'}]},
#   'public': True,
#   'created_at': '2023-02-11T22:38:31Z'},
#  {'id': '27028491395',
#   'type': 'PushEvent',
#   'actor': {'id': 41898282,
#    'login': 'github-actions[bot]',
#    'display_login': 'github-actions',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/github-actions[bot]',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/41898282?'},
#   'repo': {'id': 505469659,
#    'name': 'akky/statusbase-nuxt',
#    'url': 'https://api.github.com/repos/akky/statusbase-nuxt'},
#   'payload': {'repository_id': 505469659,
#    'push_id': 12589693211,
#    'size': 1,
#    'distinct_size': 1,
#    'ref': 'refs/heads/master',
#    'head': '58b5eee3735e9c0c4b1d8ac84ab066cf913dffb7',
#    'before': '4e3a758b2f3d771f6405a2029a2569eb837879e5',
#    'commits': [{'sha': '58b5eee3735e9c0c4b1d8ac84ab066cf913dffb7',
#      'author': {'email': 'zernonia@gmail.com', 'name': 'zernonia'},
#      'message': '[Automated] Update Health Check Logs',
#      'distinct': True,
#      'url': 'https://api.github.com/repos/akky/statusbase-nuxt/commits/58b5eee3735e9c0c4b1d8ac84ab066cf913dffb7'}]},
#   'public': True,
#   'created_at': '2023-02-11T22:38:31Z'},
#  {'id': '27028491414',
#   'type': 'ForkEvent',
#   'actor': {'id': 118617126,
#    'login': 'stebible',
#    'display_login': 'stebible',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/stebible',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/118617126?'},
#   'repo': {'id': 301425281,
#    'name': 'LandmakTechnology/kops-k8s',
#    'url': 'https://api.github.com/repos/LandmakTechnology/kops-k8s'},
#   'payload': {'forkee': {'id': 600572700,
#     'node_id': 'R_kgDOI8wDHA',
#     'name': 'kops-k8s',
#     'full_name': 'stebible/kops-k8s',
#     'private': False,
#     'owner': {'login': 'stebible',
#      'id': 118617126,
#      'node_id': 'U_kgDOBxH0Jg',
#      'avatar_url': 'https://avatars.githubusercontent.com/u/118617126?v=4',
#      'gravatar_id': '',
#      'url': 'https://api.github.com/users/stebible',
#      'html_url': 'https://github.com/stebible',
#      'followers_url': 'https://api.github.com/users/stebible/followers',
#      'following_url': 'https://api.github.com/users/stebible/following{/other_user}',
#      'gists_url': 'https://api.github.com/users/stebible/gists{/gist_id}',
#      'starred_url': 'https://api.github.com/users/stebible/starred{/owner}{/repo}',
#      'subscriptions_url': 'https://api.github.com/users/stebible/subscriptions',
#      'organizations_url': 'https://api.github.com/users/stebible/orgs',
#      'repos_url': 'https://api.github.com/users/stebible/repos',
#      'events_url': 'https://api.github.com/users/stebible/events{/privacy}',
#      'received_events_url': 'https://api.github.com/users/stebible/received_events',
#      'type': 'User',
#      'site_admin': False},
#     'html_url': 'https://github.com/stebible/kops-k8s',
#     'description': None,
#     'fork': True,
#     'url': 'https://api.github.com/repos/stebible/kops-k8s',
#     'forks_url': 'https://api.github.com/repos/stebible/kops-k8s/forks',
#     'keys_url': 'https://api.github.com/repos/stebible/kops-k8s/keys{/key_id}',
#     'collaborators_url': 'https://api.github.com/repos/stebible/kops-k8s/collaborators{/collaborator}',
#     'teams_url': 'https://api.github.com/repos/stebible/kops-k8s/teams',
#     'hooks_url': 'https://api.github.com/repos/stebible/kops-k8s/hooks',
#     'issue_events_url': 'https://api.github.com/repos/stebible/kops-k8s/issues/events{/number}',
#     'events_url': 'https://api.github.com/repos/stebible/kops-k8s/events',
#     'assignees_url': 'https://api.github.com/repos/stebible/kops-k8s/assignees{/user}',
#     'branches_url': 'https://api.github.com/repos/stebible/kops-k8s/branches{/branch}',
#     'tags_url': 'https://api.github.com/repos/stebible/kops-k8s/tags',
#     'blobs_url': 'https://api.github.com/repos/stebible/kops-k8s/git/blobs{/sha}',
#     'git_tags_url': 'https://api.github.com/repos/stebible/kops-k8s/git/tags{/sha}',
#     'git_refs_url': 'https://api.github.com/repos/stebible/kops-k8s/git/refs{/sha}',
#     'trees_url': 'https://api.github.com/repos/stebible/kops-k8s/git/trees{/sha}',
#     'statuses_url': 'https://api.github.com/repos/stebible/kops-k8s/statuses/{sha}',
#     'languages_url': 'https://api.github.com/repos/stebible/kops-k8s/languages',
#     'stargazers_url': 'https://api.github.com/repos/stebible/kops-k8s/stargazers',
#     'contributors_url': 'https://api.github.com/repos/stebible/kops-k8s/contributors',
#     'subscribers_url': 'https://api.github.com/repos/stebible/kops-k8s/subscribers',
#     'subscription_url': 'https://api.github.com/repos/stebible/kops-k8s/subscription',
#     'commits_url': 'https://api.github.com/repos/stebible/kops-k8s/commits{/sha}',
#     'git_commits_url': 'https://api.github.com/repos/stebible/kops-k8s/git/commits{/sha}',
#     'comments_url': 'https://api.github.com/repos/stebible/kops-k8s/comments{/number}',
#     'issue_comment_url': 'https://api.github.com/repos/stebible/kops-k8s/issues/comments{/number}',
#     'contents_url': 'https://api.github.com/repos/stebible/kops-k8s/contents/{+path}',
#     'compare_url': 'https://api.github.com/repos/stebible/kops-k8s/compare/{base}...{head}',
#     'merges_url': 'https://api.github.com/repos/stebible/kops-k8s/merges',
#     'archive_url': 'https://api.github.com/repos/stebible/kops-k8s/{archive_format}{/ref}',
#     'downloads_url': 'https://api.github.com/repos/stebible/kops-k8s/downloads',
#     'issues_url': 'https://api.github.com/repos/stebible/kops-k8s/issues{/number}',
#     'pulls_url': 'https://api.github.com/repos/stebible/kops-k8s/pulls{/number}',
#     'milestones_url': 'https://api.github.com/repos/stebible/kops-k8s/milestones{/number}',
#     'notifications_url': 'https://api.github.com/repos/stebible/kops-k8s/notifications{?since,all,participating}',
#     'labels_url': 'https://api.github.com/repos/stebible/kops-k8s/labels{/name}',
#     'releases_url': 'https://api.github.com/repos/stebible/kops-k8s/releases{/id}',
#     'deployments_url': 'https://api.github.com/repos/stebible/kops-k8s/deployments',
#     'created_at': '2023-02-11T22:38:30Z',
#     'updated_at': '2023-02-11T14:47:21Z',
#     'pushed_at': '2023-02-11T12:53:27Z',
#     'git_url': 'git://github.com/stebible/kops-k8s.git',
#     'ssh_url': 'git@github.com:stebible/kops-k8s.git',
#     'clone_url': 'https://github.com/stebible/kops-k8s.git',
#     'svn_url': 'https://github.com/stebible/kops-k8s',
#     'homepage': None,
#     'size': 42,
#     'stargazers_count': 0,
#     'watchers_count': 0,
#     'language': None,
#     'has_issues': False,
#     'has_projects': True,
#     'has_downloads': True,
#     'has_wiki': True,
#     'has_pages': False,
#     'has_discussions': False,
#     'forks_count': 0,
#     'mirror_url': None,
#     'archived': False,
#     'disabled': False,
#     'open_issues_count': 0,
#     'license': None,
#     'allow_forking': True,
#     'is_template': False,
#     'web_commit_signoff_required': False,
#     'topics': [],
#     'visibility': 'public',
#     'forks': 0,
#     'open_issues': 0,
#     'watchers': 0,
#     'default_branch': 'main',
#     'public': True}},
#   'public': True,
#   'created_at': '2023-02-11T22:38:31Z',
#   'org': {'id': 70292662,
#    'login': 'LandmakTechnology',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/orgs/LandmakTechnology',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/70292662?'}},
#  {'id': '27028491393',
#   'type': 'ReleaseEvent',
#   'actor': {'id': 41898282,
#    'login': 'github-actions[bot]',
#    'display_login': 'github-actions',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/github-actions[bot]',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/41898282?'},
#   'repo': {'id': 388872173,
#    'name': 'gear-tech/gear',
#    'url': 'https://api.github.com/repos/gear-tech/gear'},
#   'payload': {'action': 'published',
#    'release': {'url': 'https://api.github.com/repos/gear-tech/gear/releases/92124643',
#     'assets_url': 'https://api.github.com/repos/gear-tech/gear/releases/92124643/assets',
#     'upload_url': 'https://uploads.github.com/repos/gear-tech/gear/releases/92124643/assets{?name,label}',
#     'html_url': 'https://github.com/gear-tech/gear/releases/tag/build',
#     'id': 92124643,
#     'author': {'login': 'github-actions[bot]',
#      'id': 41898282,
#      'node_id': 'MDM6Qm90NDE4OTgyODI=',
#      'avatar_url': 'https://avatars.githubusercontent.com/in/15368?v=4',
#      'gravatar_id': '',
#      'url': 'https://api.github.com/users/github-actions%5Bbot%5D',
#      'html_url': 'https://github.com/apps/github-actions',
#      'followers_url': 'https://api.github.com/users/github-actions%5Bbot%5D/followers',
#      'following_url': 'https://api.github.com/users/github-actions%5Bbot%5D/following{/other_user}',
#      'gists_url': 'https://api.github.com/users/github-actions%5Bbot%5D/gists{/gist_id}',
#      'starred_url': 'https://api.github.com/users/github-actions%5Bbot%5D/starred{/owner}{/repo}',
#      'subscriptions_url': 'https://api.github.com/users/github-actions%5Bbot%5D/subscriptions',
#      'organizations_url': 'https://api.github.com/users/github-actions%5Bbot%5D/orgs',
#      'repos_url': 'https://api.github.com/users/github-actions%5Bbot%5D/repos',
# ...
#        'name': 'GNU General Public License v2.0',
#        'spdx_id': 'GPL-2.0',
#        'url': 'https://api.github.com/licenses/gpl-2.0',
#        'node_id': 'MDc6TGljZW5zZTg='},
#       'allow_forking': True,
#       'is_template': False,
#       'web_commit_signoff_required': False,
#       'topics': ['hacktoberfest', 'jellyfin', 'media', 'videos'],
#       'visibility': 'public',
#       'forks': 719,
#       'open_issues': 274,
#       'watchers': 1149,
#       'default_branch': 'master'}},
#     '_links': {'self': {'href': 'https://api.github.com/repos/jellyfin/jellyfin-web/pulls/3906'},
#      'html': {'href': 'https://github.com/jellyfin/jellyfin-web/pull/3906'},
#      'issue': {'href': 'https://api.github.com/repos/jellyfin/jellyfin-web/issues/3906'},
#      'comments': {'href': 'https://api.github.com/repos/jellyfin/jellyfin-web/issues/3906/comments'},
#      'review_comments': {'href': 'https://api.github.com/repos/jellyfin/jellyfin-web/pulls/3906/comments'},
#      'review_comment': {'href': 'https://api.github.com/repos/jellyfin/jellyfin-web/pulls/comments{/number}'},
#      'commits': {'href': 'https://api.github.com/repos/jellyfin/jellyfin-web/pulls/3906/commits'},
#      'statuses': {'href': 'https://api.github.com/repos/jellyfin/jellyfin-web/statuses/276a59191bdc0715e61613e22f2f647d22bc34e3'}},
#     'author_association': 'CONTRIBUTOR',
#     'auto_merge': None,
#     'active_lock_reason': None}},
#   'public': True,
#   'created_at': '2023-02-11T22:38:30Z',
#   'org': {'id': 45698031,
#    'login': 'jellyfin',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/orgs/jellyfin',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/45698031?'}},
#  {'id': '27028491385',
#   'type': 'PushEvent',
#   'actor': {'id': 124638579,
#    'login': 'Jtheus',
#    'display_login': 'Jtheus',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/Jtheus',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/124638579?'},
#   'repo': {'id': 600572190,
#    'name': 'Jtheus/Meu_Portf-lio',
#    'url': 'https://api.github.com/repos/Jtheus/Meu_Portf-lio'},
#   'payload': {'repository_id': 600572190,
#    'push_id': 12589693202,
#    'size': 1,
#    'distinct_size': 1,
#    'ref': 'refs/heads/main',
#    'head': 'ca1b5b3c699900c1728c7c301998bc63281bc716',
#    'before': '6954d87b9f6a40575bf9ae4f27f57888a1ae10bc',
#    'commits': [{'sha': 'ca1b5b3c699900c1728c7c301998bc63281bc716',
#      'author': {'email': '124638579+Jtheus@users.noreply.github.com',
#       'name': 'José Mateus'},
#      'message': 'Add files via upload',
#      'distinct': True,
#      'url': 'https://api.github.com/repos/Jtheus/Meu_Portf-lio/commits/ca1b5b3c699900c1728c7c301998bc63281bc716'}]},
#   'public': True,
#   'created_at': '2023-02-11T22:38:31Z'},
#  {'id': '27028491392',
#   'type': 'PushEvent',
#   'actor': {'id': 90661690,
#    'login': 'sparkyloo',
#    'display_login': 'sparkyloo',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/sparkyloo',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/90661690?'},
#   'repo': {'id': 590753881,
#    'name': 'Derek-Emsbach/pinteresting-group-project',
#    'url': 'https://api.github.com/repos/Derek-Emsbach/pinteresting-group-project'},
#   'payload': {'repository_id': 590753881,
#    'push_id': 12589693206,
#    'size': 1,
#    'distinct_size': 1,
#    'ref': 'refs/heads/ak/saturday-dev',
#    'head': '86bb0a070b343fa82a6444d4e57d3fd75d467166',
#    'before': '22c8a70f9e6d33b13542b071197d0b053f2ae10b',
#    'commits': [{'sha': '86bb0a070b343fa82a6444d4e57d3fd75d467166',
#      'author': {'email': 'amanpreet_k32@yahoo.com', 'name': 'Aman Kaur'},
#      'message': "It can't break in many more ways, right?",
#      'distinct': True,
#      'url': 'https://api.github.com/repos/Derek-Emsbach/pinteresting-group-project/commits/86bb0a070b343fa82a6444d4e57d3fd75d467166'}]},
#   'public': True,
#   'created_at': '2023-02-11T22:38:31Z'},
#  {'id': '27028491376',
#   'type': 'PushEvent',
#   'actor': {'id': 61036524,
#    'login': 'Garrett12123',
#    'display_login': 'Garrett12123',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/Garrett12123',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/61036524?'},
#   'repo': {'id': 599341845,
#    'name': 'drk10015/AuburnHacks23',
#    'url': 'https://api.github.com/repos/drk10015/AuburnHacks23'},
#   'payload': {'repository_id': 599341845,
#    'push_id': 12589693204,
#    'size': 1,
#    'distinct_size': 1,
#    'ref': 'refs/heads/main',
#    'head': '6c53e5d1c83b14a2a74093afcedb70225770c60b',
#    'before': '19e1cd935069a3c8c0018e4a3b37610469981db4',
#    'commits': [{'sha': '6c53e5d1c83b14a2a74093afcedb70225770c60b',
#      'author': {'email': '61036524+Garrett12123@users.noreply.github.com',
#       'name': 'Bradley Flowers'},
#      'message': 'Add files via upload\n\nfirst GUI push',
#      'distinct': True,
#      'url': 'https://api.github.com/repos/drk10015/AuburnHacks23/commits/6c53e5d1c83b14a2a74093afcedb70225770c60b'}]},
#   'public': True,
#   'created_at': '2023-02-11T22:38:31Z'},
#  {'id': '27028491364',
#   'type': 'PushEvent',
#   'actor': {'id': 9460517,
#    'login': 'ronghuaxueleng',
#    'display_login': 'ronghuaxueleng',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/ronghuaxueleng',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/9460517?'},
#   'repo': {'id': 523652231,
#    'name': 'ronghuaxueleng/qiandao',
#    'url': 'https://api.github.com/repos/ronghuaxueleng/qiandao'},
#   'payload': {'repository_id': 523652231,
#    'push_id': 12589693191,
#    'size': 1,
#    'distinct_size': 1,
#    'ref': 'refs/heads/qiandao',
#    'head': '6a98d2645039a1c636443f33b645cb2dd3adea54',
#    'before': '2d5410d67d54a1c30a60ee0da72e26855898f185',
#    'commits': [{'sha': '6a98d2645039a1c636443f33b645cb2dd3adea54',
#      'author': {'email': 'caoqianghappy@126.com', 'name': 'caoqiang'},
#      'message': 'up',
#      'distinct': True,
#      'url': 'https://api.github.com/repos/ronghuaxueleng/qiandao/commits/6a98d2645039a1c636443f33b645cb2dd3adea54'}]},
#   'public': True,
#   'created_at': '2023-02-11T22:38:30Z'},
#  {'id': '27028491373',
#   'type': 'IssueCommentEvent',
#   'actor': {'id': 11161434,
#    'login': 'cnaslain',
#    'display_login': 'cnaslain',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/cnaslain',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/11161434?'},
#   'repo': {'id': 128636610,
#    'name': 'Koenkk/zigbee2mqtt',
#    'url': 'https://api.github.com/repos/Koenkk/zigbee2mqtt'},
#   'payload': {'action': 'created',
#    'issue': {'url': 'https://api.github.com/repos/Koenkk/zigbee2mqtt/issues/1310',
#     'repository_url': 'https://api.github.com/repos/Koenkk/zigbee2mqtt',
#     'labels_url': 'https://api.github.com/repos/Koenkk/zigbee2mqtt/issues/1310/labels{/name}',
#     'comments_url': 'https://api.github.com/repos/Koenkk/zigbee2mqtt/issues/1310/comments',
#     'events_url': 'https://api.github.com/repos/Koenkk/zigbee2mqtt/issues/1310/events',
#     'html_url': 'https://github.com/Koenkk/zigbee2mqtt/issues/1310',
#     'id': 424538625,
#     'node_id': 'MDU6SXNzdWU0MjQ1Mzg2MjU=',
#     'number': 1310,
#     'title': 'proposal: add Docker healthcheck',
#     'user': {'login': 'thewilli',
#      'id': 1206639,
#      'node_id': 'MDQ6VXNlcjEyMDY2Mzk=',
#      'avatar_url': 'https://avatars.githubusercontent.com/u/1206639?v=4',
#      'gravatar_id': '',
#      'url': 'https://api.github.com/users/thewilli',
#      'html_url': 'https://github.com/thewilli',
#      'followers_url': 'https://api.github.com/users/thewilli/followers',
#      'following_url': 'https://api.github.com/users/thewilli/following{/other_user}',
#      'gists_url': 'https://api.github.com/users/thewilli/gists{/gist_id}',
#      'starred_url': 'https://api.github.com/users/thewilli/starred{/owner}{/repo}',
#      'subscriptions_url': 'https://api.github.com/users/thewilli/subscriptions',
#      'organizations_url': 'https://api.github.com/users/thewilli/orgs',
#      'repos_url': 'https://api.github.com/users/thewilli/repos',
#      'events_url': 'https://api.github.com/users/thewilli/events{/privacy}',
#      'received_events_url': 'https://api.github.com/users/thewilli/received_events',
#      'type': 'User',
#      'site_admin': False},
#     'labels': [{'id': 894537366,
#       'node_id': 'MDU6TGFiZWw4OTQ1MzczNjY=',
#       'url': 'https://api.github.com/repos/Koenkk/zigbee2mqtt/labels/feature%20request',
#       'name': 'feature request',
#       'color': 'a2eeef',
#       'default': False,
#       'description': 'Feature request'},
#      {'id': 979833647,
#       'node_id': 'MDU6TGFiZWw5Nzk4MzM2NDc=',
#       'url': 'https://api.github.com/repos/Koenkk/zigbee2mqtt/labels/stale',
#       'name': 'stale',
#       'color': '0e8a16',
#       'default': False,
#       'description': 'Stale issues'}],
#     'state': 'closed',
#     'locked': False,
#     'assignee': None,
#     'assignees': [],
#     'milestone': None,
#     'comments': 22,
#     'created_at': '2019-03-23T19:56:06Z',
#     'updated_at': '2023-02-11T22:38:30Z',
#     'closed_at': '2019-10-15T15:28:20Z',
#     'author_association': 'CONTRIBUTOR',
#     'active_lock_reason': None,
#     'body': 'The Docker container is great to run zigbee2mqtt as a "controlled, predefined environment". The only thing that I\'m currently missing and would propose to add are [health checks](https://docs.docker.com/engine/reference/builder/#healthcheck).\r\n\r\nIf health checks were integreated, we could use monitoring and alerting systems to informat about the system being in an unusable state - or just restart the container.\r\n\r\nThose *unhealthy* states might include:\r\n\r\n* CC2531 no longer available (#1308)\r\n* MQTT Server not reachable / MQTT authentication failed\r\n* (maybe) certain devices marked as *important* are not available\r\n\r\n ',
#     'reactions': {'url': 'https://api.github.com/repos/Koenkk/zigbee2mqtt/issues/1310/reactions',
#      'total_count': 6,
#      '+1': 6,
#      '-1': 0,
#      'laugh': 0,
#      'hooray': 0,
#      'confused': 0,
#      'heart': 0,
#      'rocket': 0,
#      'eyes': 0},
#     'timeline_url': 'https://api.github.com/repos/Koenkk/zigbee2mqtt/issues/1310/timeline',
#     'performed_via_github_app': None,
#     'state_reason': 'completed'},
#    'comment': {'url': 'https://api.github.com/repos/Koenkk/zigbee2mqtt/issues/comments/1426890581',
#     'html_url': 'https://github.com/Koenkk/zigbee2mqtt/issues/1310#issuecomment-1426890581',
#     'issue_url': 'https://api.github.com/repos/Koenkk/zigbee2mqtt/issues/1310',
#     'id': 1426890581,
#     'node_id': 'IC_kwDOB6rWws5VDJ9V',
#     'user': {'login': 'cnaslain',
#      'id': 11161434,
#      'node_id': 'MDQ6VXNlcjExMTYxNDM0',
#      'avatar_url': 'https://avatars.githubusercontent.com/u/11161434?v=4',
#      'gravatar_id': '',
#      'url': 'https://api.github.com/users/cnaslain',
#      'html_url': 'https://github.com/cnaslain',
#      'followers_url': 'https://api.github.com/users/cnaslain/followers',
#      'following_url': 'https://api.github.com/users/cnaslain/following{/other_user}',
#      'gists_url': 'https://api.github.com/users/cnaslain/gists{/gist_id}',
#      'starred_url': 'https://api.github.com/users/cnaslain/starred{/owner}{/repo}',
#      'subscriptions_url': 'https://api.github.com/users/cnaslain/subscriptions',
#      'organizations_url': 'https://api.github.com/users/cnaslain/orgs',
#      'repos_url': 'https://api.github.com/users/cnaslain/repos',
#      'events_url': 'https://api.github.com/users/cnaslain/events{/privacy}',
#      'received_events_url': 'https://api.github.com/users/cnaslain/received_events',
#      'type': 'User',
#      'site_admin': False},
#     'created_at': '2023-02-11T22:38:30Z',
#     'updated_at': '2023-02-11T22:38:30Z',
#     'author_association': 'NONE',
#     'body': "I would love having an healtheck solution. It's important that docker/kubernetes restarts the container if something goes wrong.\r\nDoes anyone found a workaround to an app hack?",
#     'reactions': {'url': 'https://api.github.com/repos/Koenkk/zigbee2mqtt/issues/comments/1426890581/reactions',
#      'total_count': 0,
#      '+1': 0,
#      '-1': 0,
#      'laugh': 0,
#      'hooray': 0,
#      'confused': 0,
#      'heart': 0,
#      'rocket': 0,
#      'eyes': 0},
#     'performed_via_github_app': None}},
#   'public': True,
#   'created_at': '2023-02-11T22:38:31Z'},
#  {'id': '27028491375',
#   'type': 'CreateEvent',
#   'actor': {'id': 81843382,
#    'login': 'agusdeo',
#    'display_login': 'agusdeo',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/agusdeo',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/81843382?'},
#   'repo': {'id': 600571375,
#    'name': 'agusdeo/agusdeo.github.io',
#    'url': 'https://api.github.com/repos/agusdeo/agusdeo.github.io'},
#   'payload': {'ref': 'main',
#    'ref_type': 'branch',
#    'master_branch': 'main',
#    'description': None,
#    'pusher_type': 'user'},
#   'public': True,
#   'created_at': '2023-02-11T22:38:31Z'},
#  {'id': '27028491369',
#   'type': 'CreateEvent',
#   'actor': {'id': 103286126,
#    'login': 'codestar-github-bot-eu-central-1',
#    'display_login': 'codestar-github-bot-eu-central-1',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/codestar-github-bot-eu-central-1',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/103286126?'},
#   'repo': {'id': 600572696,
#    'name': 'codestar-github-bot-eu-central-1/user-public-seeded-csc-repo-eu-central-1',
#    'url': 'https://api.github.com/repos/codestar-github-bot-eu-central-1/user-public-seeded-csc-repo-eu-central-1'},
#   'payload': {'ref': None,
#    'ref_type': 'repository',
#    'master_branch': 'main',
#    'description': 'Seeded Repository created by CFN',
#    'pusher_type': 'user'},
#   'public': True,
#   'created_at': '2023-02-11T22:38:30Z'},
#  {'id': '27028491351',
#   'type': 'PushEvent',
#   'actor': {'id': 107148599,
#    'login': 'tf-vcs-testing-staging',
#    'display_login': 'tf-vcs-testing-staging',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/tf-vcs-testing-staging',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/107148599?'},
#   'repo': {'id': 600572687,
#    'name': 'tf-vcs-e2e/e2e-gh-dc351aaf-8c22-b101-8d4c-5adaf17f412d',
#    'url': 'https://api.github.com/repos/tf-vcs-e2e/e2e-gh-dc351aaf-8c22-b101-8d4c-5adaf17f412d'},
#   'payload': {'repository_id': 600572687,
#    'push_id': 12589693190,
#    'size': 1,
#    'distinct_size': 1,
#    'ref': 'refs/heads/main',
#    'head': '7a04090de53278f42adce985fc730ab798ad0f60',
#    'before': 'fea11d027289b0fef3fdcb6d140f9c31d658c4c2',
#    'commits': [{'sha': '7a04090de53278f42adce985fc730ab798ad0f60',
#      'author': {'email': 'vcs-testing+staging@hashicorp.com',
#       'name': 'tf-vcs-testing-staging'},
#      'message': 'c8e81567-e26e-35c1-cc2d-9017f648f039',
#      'distinct': True,
#      'url': 'https://api.github.com/repos/tf-vcs-e2e/e2e-gh-dc351aaf-8c22-b101-8d4c-5adaf17f412d/commits/7a04090de53278f42adce985fc730ab798ad0f60'}]},
#   'public': True,
#   'created_at': '2023-02-11T22:38:30Z',
#   'org': {'id': 94930388,
#    'login': 'tf-vcs-e2e',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/orgs/tf-vcs-e2e',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/94930388?'}},
#  {'id': '27028491353',
#   'type': 'PushEvent',
#   'actor': {'id': 41898282,
#    'login': 'github-actions[bot]',
#    'display_login': 'github-actions',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/github-actions[bot]',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/41898282?'},
#   'repo': {'id': 462900780,
#    'name': 'trinib/trinib',
#    'url': 'https://api.github.com/repos/trinib/trinib'},
#   'payload': {'repository_id': 462900780,
#    'push_id': 12589693185,
#    'size': 1,
#    'distinct_size': 1,
#    'ref': 'refs/heads/main',
#    'head': '4219ee5b62ae4007d2ad8b5871710f414b350db2',
#    'before': 'b6448cc36cfdc22baec2bcd5a324d1fcb99ae8b9',
#    'commits': [{'sha': '4219ee5b62ae4007d2ad8b5871710f414b350db2',
#      'author': {'email': '116818502+Schwifty-Bot@users.noreply.github.com',
#       'name': 'Schwifty-Bot'},
#      'message': '٩(̾●̮̮̃̾•̃̾)۶🔥ℝ𝔼𝔸𝔻𝕄𝔼 𝕌ℙ𝔻𝔸𝕋𝔼𝔻🔥٩(̾●̮̮̃̾•̃̾)۶',
#      'distinct': True,
#      'url': 'https://api.github.com/repos/trinib/trinib/commits/4219ee5b62ae4007d2ad8b5871710f414b350db2'}]},
#   'public': True,
#   'created_at': '2023-02-11T22:38:30Z'}]

# %%
# How many events are we looking at?
len(github_response)
# Out:
# 30

# %%
# What are the keys in the first event?
github_response[0].keys()
# Out:
# dict_keys(['id', 'type', 'actor', 'repo', 'payload', 'public', 'created_at', 'org'])

# %%
# We can see that 'repo' is another subdictionary.
# What are the keys in the 'repo' subdictionary?
github_response[0]['repo'].keys()
# Out:
# dict_keys(['id', 'name', 'url'])

# %%
# What's the value for the key 'name' in 'repo'?
github_response[0]['repo']['name']
# Out:
# 'pow-co/powstream.com'

# %% [markdown]
# #### Transforming a JSON into a DataFrame

# %% [markdown]
# ##### Option 1: pd.DataFrame()

# %%
# Turn it into a pandas DataFrame.
pd.DataFrame(github_response)
# Out:
#              id                           type  \
# 0   27028491443                      PushEvent
# 1   27028491449                      PushEvent
# 2   27028491440                    CreateEvent
# 3   27028491441                      PushEvent
# 4   27028491439                      PushEvent
# 5   27028491431                      PushEvent
# 6   27028491422                    CreateEvent
# 7   27028491438                    IssuesEvent
# 8   27028491434                    DeleteEvent
# 9   27028491425                      PushEvent
# 10  27028491421                    CreateEvent
# 11  27028491415                    CreateEvent
# 12  27028491419                     WatchEvent
# 13  27028491399               PullRequestEvent
# 14  27028491411                    CreateEvent
# 15  27028491403                     WatchEvent
# 16  27028491407                      PushEvent
# 17  27028491395                      PushEvent
# 18  27028491414                      ForkEvent
# 19  27028491393                   ReleaseEvent
# 20  27028491386  PullRequestReviewCommentEvent
# 21  27028491385                      PushEvent
# 22  27028491392                      PushEvent
# 23  27028491376                      PushEvent
# 24  27028491364                      PushEvent
# 25  27028491373              IssueCommentEvent
# 26  27028491375                    CreateEvent
# 27  27028491369                    CreateEvent
# 28  27028491351                      PushEvent
# 29  27028491353                      PushEvent
#
#                                                 actor  \
# 0   {'id': 4019818, 'login': 'eddiewillers', 'disp...
# 1   {'id': 41898282, 'login': 'github-actions[bot]...
# 2   {'id': 105957472, 'login': 'nathan2slime', 'di...
# 3   {'id': 70250106, 'login': 'devereauxk', 'displ...
# 4   {'id': 97152724, 'login': 'diegoarauj0', 'disp...
# 5   {'id': 43733305, 'login': 'yanonono', 'display...
# 6   {'id': 15019905, 'login': 'mikle-viter', 'disp...
# 7   {'id': 96301800, 'login': 'AjayMaheshwari23', ...
# 8   {'id': 71354125, 'login': 'aws-connector-for-g...
# 9   {'id': 107641357, 'login': 'MccMiles', 'displa...
# 10  {'id': 41898282, 'login': 'github-actions[bot]...
# 11  {'id': 110985398, 'login': 'marcgirbaub', 'dis...
# 12  {'id': 5899823, 'login': 'Saloframes', 'displa...
# 13  {'id': 4019818, 'login': 'eddiewillers', 'disp...
# 14  {'id': 10810283, 'login': 'direwolf-github', '...
# 15  {'id': 110000273, 'login': 'jasg27', 'display_...
# 16  {'id': 92614482, 'login': 'davidstephenson8', ...
# 17  {'id': 41898282, 'login': 'github-actions[bot]...
# 18  {'id': 118617126, 'login': 'stebible', 'displa...
# 19  {'id': 41898282, 'login': 'github-actions[bot]...
# 20  {'id': 56478732, 'login': 'dmitrylyzo', 'displ...
# 21  {'id': 124638579, 'login': 'Jtheus', 'display_...
# 22  {'id': 90661690, 'login': 'sparkyloo', 'displa...
# 23  {'id': 61036524, 'login': 'Garrett12123', 'dis...
# 24  {'id': 9460517, 'login': 'ronghuaxueleng', 'di...
# 25  {'id': 11161434, 'login': 'cnaslain', 'display...
# 26  {'id': 81843382, 'login': 'agusdeo', 'display_...
# 27  {'id': 103286126, 'login': 'codestar-github-bo...
# 28  {'id': 107148599, 'login': 'tf-vcs-testing-sta...
# 29  {'id': 41898282, 'login': 'github-actions[bot]...
#
#                                                  repo  \
# 0   {'id': 561198962, 'name': 'pow-co/powstream.co...
# 1   {'id': 457150042, 'name': 'Louiz-Ferraz/Louiz-...
# 2   {'id': 599342587, 'name': 'nathan2slime/spacek...
# 3   {'id': 380052777, 'name': 'devereauxk/eic_sim_...
# 4   {'id': 597862056, 'name': 'diegoarauj0/PokeDex...
# 5   {'id': 183440182, 'name': 'yanonono/booth-upda...
# 6   {'id': 584455711, 'name': 'mikle-viter/data_pr...
# 7   {'id': 350087687, 'name': 'PalisadoesFoundatio...
# 8   {'id': 429551228, 'name': 'bullet-dev-team/pyt...
# 9   {'id': 595916083, 'name': 'MccMiles/AirBnB', '...
# 10  {'id': 388872173, 'name': 'gear-tech/gear', 'u...
# 11  {'id': 595722337, 'name': 'isdi-coders-2023/Pa...
# 12  {'id': 345346677, 'name': 'NeoApplications/Neo...
# 13  {'id': 561198962, 'name': 'pow-co/powstream.co...
# 14  {'id': 600572699, 'name': 'direwolf-github/eph...
# 15  {'id': 4165675, 'name': 'smicallef/spiderfoot'...
# 16  {'id': 593865644, 'name': 'davidstephenson8/Ru...
# 17  {'id': 505469659, 'name': 'akky/statusbase-nux...
# 18  {'id': 301425281, 'name': 'LandmakTechnology/k...
# 19  {'id': 388872173, 'name': 'gear-tech/gear', 'u...
# 20  {'id': 164221924, 'name': 'jellyfin/jellyfin-w...
# 21  {'id': 600572190, 'name': 'Jtheus/Meu_Portf-li...
# 22  {'id': 590753881, 'name': 'Derek-Emsbach/pinte...
# 23  {'id': 599341845, 'name': 'drk10015/AuburnHack...
# 24  {'id': 523652231, 'name': 'ronghuaxueleng/qian...
# 25  {'id': 128636610, 'name': 'Koenkk/zigbee2mqtt'...
# 26  {'id': 600571375, 'name': 'agusdeo/agusdeo.git...
# 27  {'id': 600572696, 'name': 'codestar-github-bot...
# 28  {'id': 600572687, 'name': 'tf-vcs-e2e/e2e-gh-d...
# 29  {'id': 462900780, 'name': 'trinib/trinib', 'ur...
#
#                                               payload  public  \
# 0   {'repository_id': 561198962, 'push_id': 125896...    True
# 1   {'repository_id': 457150042, 'push_id': 125896...    True
# 2   {'ref': 'fix/track', 'ref_type': 'branch', 'ma...    True
# 3   {'repository_id': 380052777, 'push_id': 125896...    True
# 4   {'repository_id': 597862056, 'push_id': 125896...    True
# 5   {'repository_id': 183440182, 'push_id': 125896...    True
# 6   {'ref': 'Lesson_8', 'ref_type': 'branch', 'mas...    True
# 7   {'action': 'opened', 'issue': {'url': 'https:/...    True
# 8   {'ref': 'cicd-e2e-ofl6bd', 'ref_type': 'branch...    True
# 9   {'repository_id': 595916083, 'push_id': 125896...    True
# 10  {'ref': 'build', 'ref_type': 'tag', 'master_br...    True
# 11  {'ref': 'feature/test-getSingleCharacter', 're...    True
# 12                              {'action': 'started'}    True
# 13  {'action': 'closed', 'number': 17, 'pull_reque...    True
# 14  {'ref': None, 'ref_type': 'repository', 'maste...    True
# 15                              {'action': 'started'}    True
# 16  {'repository_id': 593865644, 'push_id': 125896...    True
# 17  {'repository_id': 505469659, 'push_id': 125896...    True
# 18  {'forkee': {'id': 600572700, 'node_id': 'R_kgD...    True
# 19  {'action': 'published', 'release': {'url': 'ht...    True
# 20  {'action': 'created', 'comment': {'url': 'http...    True
# 21  {'repository_id': 600572190, 'push_id': 125896...    True
# 22  {'repository_id': 590753881, 'push_id': 125896...    True
# 23  {'repository_id': 599341845, 'push_id': 125896...    True
# 24  {'repository_id': 523652231, 'push_id': 125896...    True
# 25  {'action': 'created', 'issue': {'url': 'https:...    True
# 26  {'ref': 'main', 'ref_type': 'branch', 'master_...    True
# 27  {'ref': None, 'ref_type': 'repository', 'maste...    True
# 28  {'repository_id': 600572687, 'push_id': 125896...    True
# 29  {'repository_id': 462900780, 'push_id': 125896...    True
#
#               created_at                                                org
# 0   2023-02-11T22:38:31Z  {'id': 89090814, 'login': 'pow-co', 'gravatar_...
# 1   2023-02-11T22:38:31Z                                                NaN
# 2   2023-02-11T22:38:31Z                                                NaN
# 3   2023-02-11T22:38:31Z                                                NaN
# 4   2023-02-11T22:38:31Z                                                NaN
# 5   2023-02-11T22:38:31Z                                                NaN
# 6   2023-02-11T22:38:31Z                                                NaN
# 7   2023-02-11T22:38:31Z  {'id': 24500036, 'login': 'PalisadoesFoundatio...
# 8   2023-02-11T22:38:31Z                                                NaN
# 9   2023-02-11T22:38:31Z                                                NaN
# 10  2023-02-11T22:38:31Z  {'id': 72395063, 'login': 'gear-tech', 'gravat...
# 11  2023-02-11T22:38:31Z  {'id': 120566616, 'login': 'isdi-coders-2023',...
# 12  2023-02-11T22:38:31Z  {'id': 101910870, 'login': 'NeoApplications', ...
# 13  2023-02-11T22:38:31Z  {'id': 89090814, 'login': 'pow-co', 'gravatar_...
# 14  2023-02-11T22:38:31Z                                                NaN
# 15  2023-02-11T22:38:31Z                                                NaN
# 16  2023-02-11T22:38:31Z                                                NaN
# 17  2023-02-11T22:38:31Z                                                NaN
# 18  2023-02-11T22:38:31Z  {'id': 70292662, 'login': 'LandmakTechnology',...
# 19  2023-02-11T22:38:31Z  {'id': 72395063, 'login': 'gear-tech', 'gravat...
# 20  2023-02-11T22:38:30Z  {'id': 45698031, 'login': 'jellyfin', 'gravata...
# 21  2023-02-11T22:38:31Z                                                NaN
# 22  2023-02-11T22:38:31Z                                                NaN
# 23  2023-02-11T22:38:31Z                                                NaN
# 24  2023-02-11T22:38:30Z                                                NaN
# 25  2023-02-11T22:38:31Z                                                NaN
# 26  2023-02-11T22:38:31Z                                                NaN
# 27  2023-02-11T22:38:30Z                                                NaN
# 28  2023-02-11T22:38:30Z  {'id': 94930388, 'login': 'tf-vcs-e2e', 'grava...
# 29  2023-02-11T22:38:30Z                                                NaN

# %% [markdown]
# ##### Option 2: pd.json_normalize()
# You may notice above that many columns still contain dictionaries as values. We can correct this using json_normalize().
#
# https://pandas.pydata.org/docs/reference/api/pandas.json_normalize.html

# %%
pd.json_normalize(github_response)
# Out:
#              id                    type  public            created_at  \
# 0   26921497884               ForkEvent    True  2023-02-07T10:46:30Z
# 1   26921497902             CreateEvent    True  2023-02-07T10:46:30Z
# 2   26921497867               PushEvent    True  2023-02-07T10:46:30Z
# 3   26921497882        PullRequestEvent    True  2023-02-07T10:46:30Z
# 4   26921497816             CreateEvent    True  2023-02-07T10:46:30Z
# 5   26921497791             CreateEvent    True  2023-02-07T10:46:30Z
# 6   26921497825               PushEvent    True  2023-02-07T10:46:30Z
# 7   26921497831       IssueCommentEvent    True  2023-02-07T10:46:30Z
# 8   26921497799               PushEvent    True  2023-02-07T10:46:30Z
# 9   26921497866  PullRequestReviewEvent    True  2023-02-07T10:46:30Z
# 10  26921497817               PushEvent    True  2023-02-07T10:46:30Z
# 11  26921497784               PushEvent    True  2023-02-07T10:46:30Z
# 12  26921497789             CreateEvent    True  2023-02-07T10:46:30Z
# 13  26921497824             IssuesEvent    True  2023-02-07T10:46:30Z
# 14  26921497778        PullRequestEvent    True  2023-02-07T10:46:30Z
# 15  26921497802               PushEvent    True  2023-02-07T10:46:30Z
# 16  26921497731               PushEvent    True  2023-02-07T10:46:30Z
# 17  26921497736               PushEvent    True  2023-02-07T10:46:30Z
# 18  26921497773               PushEvent    True  2023-02-07T10:46:30Z
# 19  26921497759               PushEvent    True  2023-02-07T10:46:30Z
# 20  26921497693             CreateEvent    True  2023-02-07T10:46:30Z
# 21  26921497751               ForkEvent    True  2023-02-07T10:46:30Z
# 22  26921497682             CreateEvent    True  2023-02-07T10:46:30Z
# 23  26921497710  PullRequestReviewEvent    True  2023-02-07T10:46:30Z
# 24  26921497598               PushEvent    True  2023-02-07T10:46:30Z
# 25  26921497618        PullRequestEvent    True  2023-02-07T10:46:30Z
# 26  26921497651               PushEvent    True  2023-02-07T10:46:30Z
# 27  26921497623               PushEvent    True  2023-02-07T10:46:30Z
# 28  26921497635               PushEvent    True  2023-02-07T10:46:30Z
# 29  26921497645               PushEvent    True  2023-02-07T10:46:30Z
#
#      actor.id              actor.login      actor.display_login  \
# 0   115568106                kiran3011                kiran3011
# 1    59720814              mandeepryaz              mandeepryaz
# 2   121670751  MallikarjunaRudraniTech  MallikarjunaRudraniTech
# 3    49699333          dependabot[bot]               dependabot
# 4    17324858                  mhamzeh                  mhamzeh
# 5   124640231               uuid2com90               uuid2com90
# 6   122977688             PhoenixAlina             PhoenixAlina
# 7    60312583               BenBaryoPX               BenBaryoPX
# 8    41898282      github-actions[bot]           github-actions
# 9    57792741                kruithofa                kruithofa
# 10   98068926             BlackProfile             BlackProfile
# 11  111080417                Gathoni97                Gathoni97
# 12  106812668                FATboy331                FATboy331
# 13   54890287                nrukavkov                nrukavkov
# 14   11669178             ArturHanusek             ArturHanusek
# 15   39694318              Vitalii1991              Vitalii1991
# 16  122137731          akshayaponnuvel          akshayaponnuvel
# 17   63263301                 KidPudel                 KidPudel
# 18   41898282      github-actions[bot]           github-actions
# 19   22192134                simbelmas                simbelmas
# 20   63219344          haseeb-techsavy          haseeb-techsavy
# 21  124119609                Rockyfach                Rockyfach
# 22  124639149               uuid2com87               uuid2com87
# 23   15630211                 CorvusYe                 CorvusYe
# 24   66120736                Severnity                Severnity
# 25  122977688             PhoenixAlina             PhoenixAlina
# 26   18440250                   k-wall                   k-wall
# 27  111131774          Terminal101Team          Terminal101Team
# 28   99490674  redhat-appstudio-qe-bot  redhat-appstudio-qe-bot
# 29     784417              tsmacdonald              tsmacdonald
#
#    actor.gravatar_id                                          actor.url  \
# 0                                https://api.github.com/users/kiran3011
# 1                              https://api.github.com/users/mandeepryaz
# 2                     https://api.github.com/users/MallikarjunaRudra...
# 3                          https://api.github.com/users/dependabot[bot]
# 4                                  https://api.github.com/users/mhamzeh
# 5                               https://api.github.com/users/uuid2com90
# 6                             https://api.github.com/users/PhoenixAlina
# 7                               https://api.github.com/users/BenBaryoPX
# 8                      https://api.github.com/users/github-actions[bot]
# 9                                https://api.github.com/users/kruithofa
# 10                            https://api.github.com/users/BlackProfile
# 11                               https://api.github.com/users/Gathoni97
# 12                               https://api.github.com/users/FATboy331
# 13                               https://api.github.com/users/nrukavkov
# 14                            https://api.github.com/users/ArturHanusek
# 15                             https://api.github.com/users/Vitalii1991
# 16                         https://api.github.com/users/akshayaponnuvel
# 17                                https://api.github.com/users/KidPudel
# 18                     https://api.github.com/users/github-actions[bot]
# 19                               https://api.github.com/users/simbelmas
# 20                         https://api.github.com/users/haseeb-techsavy
# 21                               https://api.github.com/users/Rockyfach
# 22                              https://api.github.com/users/uuid2com87
# 23                                https://api.github.com/users/CorvusYe
# 24                               https://api.github.com/users/Severnity
# 25                            https://api.github.com/users/PhoenixAlina
# 26                                  https://api.github.com/users/k-wall
# 27                         https://api.github.com/users/Terminal101Team
# 28                    https://api.github.com/users/redhat-appstudio-...
# 29                             https://api.github.com/users/tsmacdonald
#
#                                      actor.avatar_url  ...  \
# 0   https://avatars.githubusercontent.com/u/115568...  ...
# 1   https://avatars.githubusercontent.com/u/59720814?  ...
# 2   https://avatars.githubusercontent.com/u/121670...  ...
# 3   https://avatars.githubusercontent.com/u/49699333?  ...
# 4   https://avatars.githubusercontent.com/u/17324858?  ...
# 5   https://avatars.githubusercontent.com/u/124640...  ...
# 6   https://avatars.githubusercontent.com/u/122977...  ...
# 7   https://avatars.githubusercontent.com/u/60312583?  ...
# 8   https://avatars.githubusercontent.com/u/41898282?  ...
# 9   https://avatars.githubusercontent.com/u/57792741?  ...
# 10  https://avatars.githubusercontent.com/u/98068926?  ...
# 11  https://avatars.githubusercontent.com/u/111080...  ...
# 12  https://avatars.githubusercontent.com/u/106812...  ...
# 13  https://avatars.githubusercontent.com/u/54890287?  ...
# 14  https://avatars.githubusercontent.com/u/11669178?  ...
# 15  https://avatars.githubusercontent.com/u/39694318?  ...
# 16  https://avatars.githubusercontent.com/u/122137...  ...
# 17  https://avatars.githubusercontent.com/u/63263301?  ...
# 18  https://avatars.githubusercontent.com/u/41898282?  ...
# 19  https://avatars.githubusercontent.com/u/22192134?  ...
# 20  https://avatars.githubusercontent.com/u/63219344?  ...
# 21  https://avatars.githubusercontent.com/u/124119...  ...
# 22  https://avatars.githubusercontent.com/u/124639...  ...
# 23  https://avatars.githubusercontent.com/u/15630211?  ...
# 24  https://avatars.githubusercontent.com/u/66120736?  ...
# 25  https://avatars.githubusercontent.com/u/122977...  ...
# 26  https://avatars.githubusercontent.com/u/18440250?  ...
# 27  https://avatars.githubusercontent.com/u/111131...  ...
# 28  https://avatars.githubusercontent.com/u/99490674?  ...
# 29    https://avatars.githubusercontent.com/u/784417?  ...
#
#          payload.pull_request.merged_by.following_url  \
# 0                                                 NaN
# 1                                                 NaN
# 2                                                 NaN
# 3                                                 NaN
# 4                                                 NaN
# 5                                                 NaN
# 6                                                 NaN
# 7                                                 NaN
# 8                                                 NaN
# 9                                                 NaN
# 10                                                NaN
# 11                                                NaN
# 12                                                NaN
# 13                                                NaN
# 14                                                NaN
# 15                                                NaN
# 16                                                NaN
# 17                                                NaN
# 18                                                NaN
# 19                                                NaN
# 20                                                NaN
# 21                                                NaN
# 22                                                NaN
# 23                                                NaN
# 24                                                NaN
# 25  https://api.github.com/users/PhoenixAlina/foll...
# 26                                                NaN
# 27                                                NaN
# 28                                                NaN
# 29                                                NaN
#
#              payload.pull_request.merged_by.gists_url  \
# 0                                                 NaN
# 1                                                 NaN
# 2                                                 NaN
# 3                                                 NaN
# 4                                                 NaN
# 5                                                 NaN
# 6                                                 NaN
# 7                                                 NaN
# 8                                                 NaN
# 9                                                 NaN
# 10                                                NaN
# 11                                                NaN
# 12                                                NaN
# 13                                                NaN
# 14                                                NaN
# 15                                                NaN
# 16                                                NaN
# 17                                                NaN
# 18                                                NaN
# 19                                                NaN
# 20                                                NaN
# 21                                                NaN
# 22                                                NaN
# 23                                                NaN
# 24                                                NaN
# 25  https://api.github.com/users/PhoenixAlina/gist...
# 26                                                NaN
# 27                                                NaN
# 28                                                NaN
# 29                                                NaN
#
#            payload.pull_request.merged_by.starred_url  \
# 0                                                 NaN
# 1                                                 NaN
# 2                                                 NaN
# 3                                                 NaN
# 4                                                 NaN
# 5                                                 NaN
# 6                                                 NaN
# 7                                                 NaN
# 8                                                 NaN
# 9                                                 NaN
# 10                                                NaN
# 11                                                NaN
# 12                                                NaN
# 13                                                NaN
# 14                                                NaN
# 15                                                NaN
# 16                                                NaN
# 17                                                NaN
# 18                                                NaN
# 19                                                NaN
# 20                                                NaN
# 21                                                NaN
# 22                                                NaN
# 23                                                NaN
# 24                                                NaN
# 25  https://api.github.com/users/PhoenixAlina/star...
# 26                                                NaN
# 27                                                NaN
# 28                                                NaN
# 29                                                NaN
#
#      payload.pull_request.merged_by.subscriptions_url  \
# 0                                                 NaN
# 1                                                 NaN
# 2                                                 NaN
# 3                                                 NaN
# 4                                                 NaN
# 5                                                 NaN
# 6                                                 NaN
# 7                                                 NaN
# 8                                                 NaN
# 9                                                 NaN
# 10                                                NaN
# 11                                                NaN
# 12                                                NaN
# 13                                                NaN
# 14                                                NaN
# 15                                                NaN
# 16                                                NaN
# 17                                                NaN
# 18                                                NaN
# 19                                                NaN
# 20                                                NaN
# 21                                                NaN
# 22                                                NaN
# 23                                                NaN
# 24                                                NaN
# 25  https://api.github.com/users/PhoenixAlina/subs...
# 26                                                NaN
# 27                                                NaN
# 28                                                NaN
# 29                                                NaN
#
#    payload.pull_request.merged_by.organizations_url  \
# 0                                               NaN
# 1                                               NaN
# 2                                               NaN
# 3                                               NaN
# 4                                               NaN
# 5                                               NaN
# 6                                               NaN
# 7                                               NaN
# 8                                               NaN
# 9                                               NaN
# 10                                              NaN
# 11                                              NaN
# 12                                              NaN
# 13                                              NaN
# 14                                              NaN
# 15                                              NaN
# 16                                              NaN
# 17                                              NaN
# 18                                              NaN
# 19                                              NaN
# 20                                              NaN
# 21                                              NaN
# 22                                              NaN
# 23                                              NaN
# 24                                              NaN
# 25   https://api.github.com/users/PhoenixAlina/orgs
# 26                                              NaN
# 27                                              NaN
# 28                                              NaN
# 29                                              NaN
#
#            payload.pull_request.merged_by.repos_url  \
# 0                                               NaN
# 1                                               NaN
# 2                                               NaN
# 3                                               NaN
# 4                                               NaN
# 5                                               NaN
# 6                                               NaN
# 7                                               NaN
# 8                                               NaN
# 9                                               NaN
# 10                                              NaN
# 11                                              NaN
# 12                                              NaN
# 13                                              NaN
# 14                                              NaN
# 15                                              NaN
# 16                                              NaN
# 17                                              NaN
# 18                                              NaN
# 19                                              NaN
# 20                                              NaN
# 21                                              NaN
# 22                                              NaN
# 23                                              NaN
# 24                                              NaN
# 25  https://api.github.com/users/PhoenixAlina/repos
# 26                                              NaN
# 27                                              NaN
# 28                                              NaN
# 29                                              NaN
#
#             payload.pull_request.merged_by.events_url  \
# 0                                                 NaN
# 1                                                 NaN
# 2                                                 NaN
# 3                                                 NaN
# 4                                                 NaN
# 5                                                 NaN
# 6                                                 NaN
# 7                                                 NaN
# 8                                                 NaN
# 9                                                 NaN
# 10                                                NaN
# 11                                                NaN
# 12                                                NaN
# 13                                                NaN
# 14                                                NaN
# 15                                                NaN
# 16                                                NaN
# 17                                                NaN
# 18                                                NaN
# 19                                                NaN
# 20                                                NaN
# 21                                                NaN
# 22                                                NaN
# 23                                                NaN
# 24                                                NaN
# 25  https://api.github.com/users/PhoenixAlina/even...
# 26                                                NaN
# 27                                                NaN
# 28                                                NaN
# 29                                                NaN
#
#    payload.pull_request.merged_by.received_events_url  \
# 0                                                 NaN
# 1                                                 NaN
# 2                                                 NaN
# 3                                                 NaN
# 4                                                 NaN
# 5                                                 NaN
# 6                                                 NaN
# 7                                                 NaN
# 8                                                 NaN
# 9                                                 NaN
# 10                                                NaN
# 11                                                NaN
# 12                                                NaN
# 13                                                NaN
# 14                                                NaN
# 15                                                NaN
# 16                                                NaN
# 17                                                NaN
# 18                                                NaN
# 19                                                NaN
# 20                                                NaN
# 21                                                NaN
# 22                                                NaN
# 23                                                NaN
# 24                                                NaN
# 25  https://api.github.com/users/PhoenixAlina/rece...
# 26                                                NaN
# 27                                                NaN
# 28                                                NaN
# 29                                                NaN
#
#    payload.pull_request.merged_by.type  \
# 0                                  NaN
# 1                                  NaN
# 2                                  NaN
# 3                                  NaN
# 4                                  NaN
# 5                                  NaN
# 6                                  NaN
# 7                                  NaN
# 8                                  NaN
# 9                                  NaN
# 10                                 NaN
# 11                                 NaN
# 12                                 NaN
# 13                                 NaN
# 14                                 NaN
# 15                                 NaN
# 16                                 NaN
# 17                                 NaN
# 18                                 NaN
# 19                                 NaN
# 20                                 NaN
# 21                                 NaN
# 22                                 NaN
# 23                                 NaN
# 24                                 NaN
# 25                                User
# 26                                 NaN
# 27                                 NaN
# 28                                 NaN
# 29                                 NaN
#
#     payload.pull_request.merged_by.site_admin
# 0                                         NaN
# 1                                         NaN
# 2                                         NaN
# 3                                         NaN
# 4                                         NaN
# 5                                         NaN
# 6                                         NaN
# 7                                         NaN
# 8                                         NaN
# 9                                         NaN
# 10                                        NaN
# 11                                        NaN
# 12                                        NaN
# 13                                        NaN
# 14                                        NaN
# 15                                        NaN
# 16                                        NaN
# 17                                        NaN
# 18                                        NaN
# 19                                        NaN
# 20                                        NaN
# 21                                        NaN
# 22                                        NaN
# 23                                        NaN
# 24                                        NaN
# 25                                      False
# 26                                        NaN
# 27                                        NaN
# 28                                        NaN
# 29                                        NaN
#
# [30 rows x 600 columns]

# %% [markdown]
# #### Selecting only certain values by iterating with a for loop
#
# If we only want to select certain parts of the JSON:
# - Option 1: make a DataFrame and drop the rest.
# - Option 2: Use a for loop to extract only the required information.
#
# https://www.w3schools.com/python/python_for_loops.asp
#
# https://www.w3schools.com/python/ref_func_range.asp

# %%
# login - first value
github_response[0]['actor']['login']
# Out:
# 'kiran3011'

# %%
# repo - first value
github_response[0]['repo']['name']
# Out:
# 'awsdevops009/Jenkins_class1'

# %%
# event_type - first value
github_response[0]['type']
# Out:
# 'ForkEvent'

# %%
# Empty lists that the loop will fill with values.
login = []
repo = []
event_type = []

for i in range(len(github_response)):
    # add the ith login value to the login list
    login.append(github_response[i]['actor']['login'])
    # add the ith repo name to the repo list
    repo.append(github_response[i]['repo']['name'])
    # add the ith event type to the event_type list
    event_type.append(github_response[i]['type'])

# %%
# Let's have a look at the login list.
login
# Out:
# ['kiran3011',
#  'mandeepryaz',
#  'MallikarjunaRudraniTech',
#  'dependabot[bot]',
#  'mhamzeh',
#  'uuid2com90',
#  'PhoenixAlina',
#  'BenBaryoPX',
#  'github-actions[bot]',
#  'kruithofa',
#  'BlackProfile',
#  'Gathoni97',
#  'FATboy331',
#  'nrukavkov',
#  'ArturHanusek',
#  'Vitalii1991',
#  'akshayaponnuvel',
#  'KidPudel',
#  'github-actions[bot]',
#  'simbelmas',
#  'haseeb-techsavy',
#  'Rockyfach',
#  'uuid2com87',
#  'CorvusYe',
#  'Severnity',
#  'PhoenixAlina',
#  'k-wall',
#  'Terminal101Team',
#  'redhat-appstudio-qe-bot',
#  'tsmacdonald']

# %%
# Let's have a look at the repo list.
repo
# Out:
# ['awsdevops009/Jenkins_class1',
#  'ryazio/.github',
#  'Arjun-m-99/testAPIs',
#  'Y0dax/Oratio',
#  'mhamzeh/sxo-worklows-cl2023',
#  'uuid2com90/99_21381',
#  'PhoenixAlina/FrontbyteAS',
#  'PerimeterX/restringer',
#  'syly315531/Proxy',
#  'zephyrproject-rtos/zephyr',
#  'BlackProfile/Music-Player',
#  'Gathoni97/alx-higher_level_programming',
#  'FATboy331/Geek-Media',
#  'Zombie-Action/monitor',
#  'codingcab/management.products.api',
#  'Vitalii1991/goit-markup-hw-07',
#  'akshayaponnuvel/Demo1',
#  'KidPudel/flutter-starter-kit',
#  'heqihua963/Proxy',
#  'simbelmas/dockerfiles',
#  'haseeb-techsavy/webapp_CICD',
#  'ine-rmotr-curriculum/ds-content-interactive-jupyterlab-tutorial',
#  'uuid2com87/76_13938',
#  'nebula-contrib/ngbatis',
#  'IRPTeam/IRP',
#  'PhoenixAlina/FrontbyteAS',
#  'k-wall/kas-installer',
#  'Terminal101-Backend/Terminal101.Backend.Flight',
#  'redhat-appstudio-qe/test-app-lebr-R2FLD-intend-study',
#  'metabase/metabase']

# %%
# Let's have a look at the event_type list.
event_type
# Out:
# ['ForkEvent',
#  'CreateEvent',
#  'PushEvent',
#  'PullRequestEvent',
#  'CreateEvent',
#  'CreateEvent',
#  'PushEvent',
#  'IssueCommentEvent',
#  'PushEvent',
#  'PullRequestReviewEvent',
#  'PushEvent',
#  'PushEvent',
#  'CreateEvent',
#  'IssuesEvent',
#  'PullRequestEvent',
#  'PushEvent',
#  'PushEvent',
#  'PushEvent',
#  'PushEvent',
#  'PushEvent',
#  'CreateEvent',
#  'ForkEvent',
#  'CreateEvent',
#  'PullRequestReviewEvent',
#  'PushEvent',
#  'PullRequestEvent',
#  'PushEvent',
#  'PushEvent',
#  'PushEvent',
#  'PushEvent']

# %% [markdown]
# ### International Space Station API - just another cool API
#
# Send a simple `get` request to know where the ISS is right now.
#
# Docs here: http://open-notify.org/Open-Notify-API/ISS-Location-Now/

# %%
url = "http://api.open-notify.org/iss-now.json"

# %%
response = requests.get(url)

# %%
response.json()
# Out:
# {'iss_position': {'latitude': '7.0014', 'longitude': '-43.4808'},
#  'message': 'success',
#  'timestamp': 1675767091}
